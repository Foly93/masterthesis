# %% [markdown]
# ### Correction of the ML-Ready Cell-Painting Data Sets
# #### Prerequisite
# This notebook is part of the master thesis of Luis Vollmers. It uses the cell paintin data set of Bray et al. and the goal of the project is to predict pubchem assay data. Originally this notebook was concerned with pubchem AID 1030 but this might be subject to change.
# #### Introduction
# The datasets generated in ml_ready of step 01 comprise several mistakes that have been made and that need to be corrected within this jupyter notebook. Mostly, the compounds listed in the rows of the ML-ready dataframes are not unique, due to a misunderstanding stemming from the Bray et al Cell-Painting paper. It was stated that the Metadata_broad_sample is a unique identifier which was found to be wrong. Identical compounds which were used in different concentrations and/or on different well-plates were assigned different Metadata_broad_sample values. This needs to be corrected as well as the averaging over the different column values. In the data columns, the cell painting features are listed and so far the algorithm just kept the first concentration and took the average of the respective multiplicates. The correct way of doing it however is to check how many concentrations are present and then take the median of the concentration that is most frequent which is done by this jupyter notebook.
# #### Summary of the steps in this notebook
# 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# 2. Reintroduce the center median data into the pubchem df
# 3. Treat the multi-concentration Compounds adequately
# 4. Export the output

# %%
import pandas as pd

# %% [markdown]
# #### 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# - Inputs are taken from the directory for step 1 of the pubchem assays and from the preprocessing directory
# - the data from cp_1030 is erroneous but the meta data is needed for the overlap with the center median data
# - therefore filter the df for the metadata

# %%
pd.set_option("display.max_rows", 300)
# define the meta cols of the pubchem assays that are relevant and filter the df 
meta_cols = ['Metadata_broad_sample','PUBCHEM_ACTIVITY_OUTCOME', 'PUBCHEM_ACTIVITY_SCORE']

# load the data into RAM 'cp_1030' can be used as a variable for a bash script
dataset_path='../../01-FilteringAssays/ml_ready/cp_504847.csv'
df = pd.read_csv(dataset_path, usecols=meta_cols)

# read the cell-painting data into RAM
cp = pd.read_csv('../../../preprocessing/cp_center_median.csv', index_col=0)

# %% [markdown]
# #### 2. Reintroduce the Center Median Data into the Pubchem DF
# - the common column is Metadata_broad_sample which was responsible for the errors in the first place
# - it is actually the only identifier column that is left in the ML-ready df
# - the inner merge makes sure that only rows are kept that can be found in both dataframes

# %%
# merge the cp and the assay data on the common column
merged = pd.merge(left=cp, right=df, on='Metadata_broad_sample', how='inner')

# %%
# this cell calculates the number of rows expected from the final dataframe
multi_list = []
concs_list = merged.CAN_SMILES.value_counts().to_list()

for i in concs_list:
    if i > 1:
        multi_list.append(i)
        
merged.shape[0]-sum(multi_list)+len(multi_list)
# Out:
# 8454

# %% [markdown]
# #### 3. Treat the multi-concentration Compounds adequately
# - this step is the only one that needs to be conducted manually
# - first look at the multi conc compounds and determine how to treat them
# - in this case the concentrations that are less frequent are dropped and the remaining ones are calculated into median
# - for that purpose the merged DF is split into data and meta columns and only the data columns are treated accordingly
# - the groupby method is used to calculate the compound wise median
# - the single concentrations are already calculated so only the multi concs are actually computed herein

# %%
# have a look at the multi concentration compounds and figure out how to treat them
merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']] # only uncomment if you havent checked for said compounds yet
# Out:
#                                              CAN_SMILES  \
# 9179              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9180              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9181              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9182              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9183              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9184              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9185              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9186              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9187              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9188              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9189              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9190              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9191              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9192              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9193              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9194              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9195  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9196  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9197  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9198  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9199  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9200  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9201  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9202  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9203  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9204  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9205  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9206  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9207  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9208  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9209  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9210  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9211  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9212  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9213  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9214  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9215  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9216  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9217  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9218  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9219  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9220  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9221  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9222  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9223  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9224  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9225  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9226  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9227                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9228                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9229                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9230                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9231                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9232                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9233                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9234                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9235                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9236                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9237                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9238                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9239                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9240                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9241                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9242                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9243  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9244  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9245  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9246  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9247  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9248  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9249  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9250  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9251  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9252  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9253  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9254  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9255  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9256  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9257  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9258  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9259  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9260  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9261  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9262  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9263  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9264  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9265  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9266  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9267  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9268  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9269  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9270  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9271                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9272                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9273                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9274                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9275                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9276                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9277              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9278              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9279              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9280              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9281              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9282              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9283              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9284              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
#
#       Metadata_mmoles_per_liter
# 9179                   3.580507
# 9180                   3.580507
# 9181                   3.580507
# 9182                   3.580507
# 9183                   3.580507
# 9184                   3.580507
# 9185                   3.580507
# 9186                   3.580507
# 9187                   3.580507
# 9188                   3.580507
# 9189                   3.580507
# 9190                   3.580507
# 9191                   3.580507
# 9192                   3.580507
# 9193                   3.580507
# 9194                   3.580507
# 9195                   2.120111
# 9196                   2.120111
# 9197                   2.120111
# 9198                   2.120111
# 9199                   2.120111
# 9200                   2.120111
# 9201                   2.120111
# 9202                   2.120111
# 9203                   2.120111
# 9204                   2.120111
# 9205                   2.120111
# 9206                   2.120111
# 9207                   2.120111
# 9208                   2.120111
# 9209                   2.120111
# 9210                   2.120111
# 9211                   2.120111
# 9212                   2.120111
# 9213                   2.120111
# 9214                   2.120111
# 9215                   2.120111
# 9216                   2.120111
# 9217                   2.120111
# 9218                   2.120111
# 9219                   2.120111
# 9220                   2.120111
# 9221                   2.120111
# 9222                   2.120111
# 9223                   2.120111
# 9224                   2.120111
# 9225                   2.120111
# 9226                   2.120111
# 9227                   3.768872
# 9228                   3.768872
# 9229                   3.768872
# 9230                   3.768872
# 9231                   3.768872
# 9232                   3.768872
# 9233                   3.768872
# 9234                   3.768872
# 9235                   3.768872
# 9236                   3.768872
# 9237                   3.768872
# 9238                   3.768872
# 9239                   3.768872
# 9240                   3.768872
# 9241                   3.768872
# 9242                   3.768872
# 9243                   2.189620
# 9244                   2.189620
# 9245                   2.189620
# 9246                   2.189620
# 9247                   2.189620
# 9248                   2.189620
# 9249                   2.189620
# 9250                   2.189620
# 9251                   5.000000
# 9252                   5.000000
# 9253                   5.000000
# 9254                   5.000000
# 9255                   5.000000
# 9256                   5.000000
# 9257                   5.000000
# 9258                   5.000000
# 9259                   5.000000
# 9260                   5.000000
# 9261                   5.000000
# 9262                   5.000000
# 9263                   5.000000
# 9264                   5.000000
# 9265                   5.000000
# 9266                   5.000000
# 9267                   5.000000
# 9268                   5.000000
# 9269                   5.000000
# 9270                   5.000000
# 9271                   5.000000
# 9272                   5.000000
# 9273                   5.000000
# 9274                   5.000000
# 9275                   5.000000
# 9276                   5.000000
# 9277                   5.000000
# 9278                   5.000000
# 9279                   5.000000
# 9280                   5.000000
# 9281                   5.000000
# 9282                   5.000000
# 9283                   5.000000
# 9284                   5.000000

# %%
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0)].index)

# %%
# Quality Control step that makes sure only the relevant rows with the most concentrations are kept
merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']] # just needed as a one time lookup
# Out:
#                                              CAN_SMILES  \
# 9179              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9180              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9181              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9182              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9183              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9184              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9185              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9186              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9187              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9188              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9189              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9190              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9191              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9192              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9193              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9194              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 9195  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9196  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9197  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9198  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9199  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9200  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9201  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9202  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9203  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9204  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9205  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9206  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9207  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9208  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9209  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9210  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9211  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9212  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9213  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9214  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9215  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9216  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9217  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9218  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9219  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9220  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9221  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9222  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9223  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9224  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9225  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9226  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 9227                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9228                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9229                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9230                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9231                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9232                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9233                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9234                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9235                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9236                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9237                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9238                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9239                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9240                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9241                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9242                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 9243  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9244  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9245  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9246  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9247  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9248  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9249  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 9250  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
#
#       Metadata_mmoles_per_liter
# 9179                   3.580507
# 9180                   3.580507
# 9181                   3.580507
# 9182                   3.580507
# 9183                   3.580507
# 9184                   3.580507
# 9185                   3.580507
# 9186                   3.580507
# 9187                   3.580507
# 9188                   3.580507
# 9189                   3.580507
# 9190                   3.580507
# 9191                   3.580507
# 9192                   3.580507
# 9193                   3.580507
# 9194                   3.580507
# 9195                   2.120111
# 9196                   2.120111
# 9197                   2.120111
# 9198                   2.120111
# 9199                   2.120111
# 9200                   2.120111
# 9201                   2.120111
# 9202                   2.120111
# 9203                   2.120111
# 9204                   2.120111
# 9205                   2.120111
# 9206                   2.120111
# 9207                   2.120111
# 9208                   2.120111
# 9209                   2.120111
# 9210                   2.120111
# 9211                   2.120111
# 9212                   2.120111
# 9213                   2.120111
# 9214                   2.120111
# 9215                   2.120111
# 9216                   2.120111
# 9217                   2.120111
# 9218                   2.120111
# 9219                   2.120111
# 9220                   2.120111
# 9221                   2.120111
# 9222                   2.120111
# 9223                   2.120111
# 9224                   2.120111
# 9225                   2.120111
# 9226                   2.120111
# 9227                   3.768872
# 9228                   3.768872
# 9229                   3.768872
# 9230                   3.768872
# 9231                   3.768872
# 9232                   3.768872
# 9233                   3.768872
# 9234                   3.768872
# 9235                   3.768872
# 9236                   3.768872
# 9237                   3.768872
# 9238                   3.768872
# 9239                   3.768872
# 9240                   3.768872
# 9241                   3.768872
# 9242                   3.768872
# 9243                   2.189620
# 9244                   2.189620
# 9245                   2.189620
# 9246                   2.189620
# 9247                   2.189620
# 9248                   2.189620
# 9249                   2.189620
# 9250                   2.189620

# %%
# define a list of the all columns of the merged data frame
all_cols = merged.columns.to_list()
# redefine meta columns with the meta information of the cell painting assay
meta_cols = ['CAN_SMILES','CPD_SMILES','Metadata_broad_sample','Metadata_Plate_Map_Name','Metadata_ASSAY_WELL_ROLE','Metadata_Plate','SINGLE_CONC','PUBCHEM_ACTIVITY_SCORE','PUBCHEM_ACTIVITY_OUTCOME']

# %%
# data cols are basically all columns without the meta data. hence the forloop that removes those from data_cols
data_cols = all_cols
for item in meta_cols:
    data_cols.remove(item)
    
# afterwards the 'CAN_SMILES' column is inserted at the first position
data_cols.insert(0,'CAN_SMILES')

# %%
# the merged data frame is split into two dataframes containing meta and raw data information
merged_data = merged.loc[:,data_cols]
merged_meta = merged.loc[:,meta_cols]

# %%
# this command takes the compound wise median of the data
merged_data = merged_data.groupby('CAN_SMILES').median().reset_index()

# %% [markdown]
# #### 4. Export the Output
# - as a last step the only thing that needs to be done is to merge the meta and data columns back into one DF
# - a bit of a clean up needs to be done since the merge command creates suplicates, which can be safely deleted
# - output in csv format named according to the pubchem AID

# %%
# the median data is merged back with the meta data
merged = pd.merge(left=merged_meta, right=merged_data, on='CAN_SMILES', how='left')

# %%
# merging generally keeps all rows in both frames so that duplicates are generated, which get hereby deleted
merged = merged.drop_duplicates(subset='CAN_SMILES')

# %%
merged.to_csv('../_output/cp_504847.csv',index=False)

# %%
pd.read_csv('../_output/cp_504847.csv') # only uncomment for quality control purposes, i.e. visual conformation
# Out:
#                                              CAN_SMILES  \
# 0                         COc1ccc2c(=O)c(CC(=O)O)coc2c1
# 1     CCCc1nc(C(C)(C)O)c(C(=O)OCc2oc(=O)oc2C)n1Cc1cc...
# 2                              COc1cc(OC)c2ccc(=O)oc2c1
# 3                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 4          O=C(CCCN1CCC(O)(c2ccc(Br)cc2)CC1)c1ccc(F)cc1
# ...                                                 ...
# 8449  CCOC(=O)c1c(C)oc2c1c(C(c1cccnc1)N1CCCCC1)c(O)c...
# 8450              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8451  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8452                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8453  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
#
#                                              CPD_SMILES  \
# 0                         COc1ccc2c(c1)occ(CC(O)=O)c2=O
# 1     CCCc1nc(C(C)(C)O)c(C(=O)OCc2oc(=O)oc2C)n1Cc1cc...
# 2                              COc1cc(OC)c2ccc(=O)oc2c1
# 3                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 4          OC1(CCN(CCCC(=O)c2ccc(F)cc2)CC1)c1ccc(Br)cc1
# ...                                                 ...
# 8449  CCOC(=O)c1c(C)oc2c1c(C(N1CCCCC1)c1cccnc1)c(O)c...
# 8450                Cn1c(cc(=O)c2ccccc12)-c1ccc2OCOc2c1
# 8451  CC(C)(C)c1ccc(cc1)C(O)CCCN1CCC(CC1)C(O)(c1cccc...
# 8452                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8453  C[C@@H]1CC[C@@]2(CC[C@]3(C)C(=CC[C@@H]4[C@@]5(...
#
#        Metadata_broad_sample Metadata_Plate_Map_Name Metadata_ASSAY_WELL_ROLE  \
# 0     BRD-K78414110-001-02-8            H-BIOA-007-3                  treated
# 1     BRD-K78485176-001-02-9            H-BIOA-007-3                  treated
# 2     BRD-K78612426-001-02-6            H-BIOA-007-3                  treated
# 3     BRD-K78633253-001-01-2            H-BIOA-007-3                  treated
# 4     BRD-K78643075-001-03-3            H-BIOA-007-3                  treated
# ...                      ...                     ...                      ...
# 8449  BRD-A43050491-001-05-6       C-2113-01-D39-007                  treated
# 8450  BRD-K92683369-001-03-6            H-BIOA-007-3                  treated
# 8451  BRD-A06352418-001-03-6            H-BIOA-001-3                  treated
# 8452  BRD-K02764365-001-03-7            H-BIOA-003-3                  treated
# 8453  BRD-K68185022-001-02-3            H-BIOA-006-3                  treated
#
#       Metadata_Plate  SINGLE_CONC  PUBCHEM_ACTIVITY_SCORE  \
# 0              24278         True                     0.0
# 1              24278         True                     0.0
# 2              24278         True                     0.0
# 3              24278         True                     0.0
# 4              24278         True                     0.0
# ...              ...          ...                     ...
# 8449           26204         True                     0.0
# 8450           24278        False                     0.0
# 8451           24294        False                     0.0
# 8452           24305        False                     0.0
# 8453           24319        False                     0.0
#
#      PUBCHEM_ACTIVITY_OUTCOME  Metadata_mmoles_per_liter  ...  \
# 0                    Inactive                   5.000000  ...
# 1                    Inactive                   5.000000  ...
# 2                    Inactive                   5.000000  ...
# 3                    Inactive                   5.000000  ...
# 4                    Inactive                   2.379167  ...
# ...                       ...                        ...  ...
# 8449                 Inactive                   5.000000  ...
# 8450                 Inactive                   3.580507  ...
# 8451                 Inactive                   2.120111  ...
# 8452                 Inactive                   3.768872  ...
# 8453                 Inactive                   2.189620  ...
#
#       Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                            0.028752                        -0.141545
# 1                           -0.046285                        -0.177514
# 2                           -0.061549                        -0.133824
# 3                            0.098785                        -0.029717
# 4                            0.208695                        -0.024429
# ...                               ...                              ...
# 8449                         0.003111                         0.057371
# 8450                        -0.104311                         0.005627
# 8451                        -0.031586                         0.058706
# 8452                         0.027589                         0.329196
# 8453                        -0.074423                        -0.081100
#
#       Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                          -0.091271                       -0.123436
# 1                          -0.196004                       -0.227765
# 2                          -0.130796                       -0.131496
# 3                          -0.036163                       -0.049478
# 4                          -0.044756                       -0.048945
# ...                              ...                             ...
# 8449                        0.013895                        0.005887
# 8450                       -0.037484                       -0.027687
# 8451                        0.032472                        0.043662
# 8452                        0.292009                        0.379255
# 8453                       -0.062452                       -0.067922
#
#       Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                             -0.234958                         -0.261659
# 1                             -0.182558                         -0.212246
# 2                             -0.153068                         -0.156526
# 3                             -0.122305                         -0.091394
# 4                             -0.091941                         -0.096263
# ...                                 ...                               ...
# 8449                          -0.003589                          0.081811
# 8450                           0.023850                         -0.032037
# 8451                           0.006015                          0.019518
# 8452                          -0.098949                         -0.160635
# 8453                          -0.003202                         -0.051394
#
#       Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                            -0.269276                          0.162881
# 1                            -0.204336                          0.087412
# 2                            -0.125545                          0.107378
# 3                            -0.115040                          0.200919
# 4                            -0.109370                          0.053506
# ...                                ...                               ...
# 8449                          0.062094                         -0.116301
# 8450                          0.004835                         -0.078895
# 8451                          0.049757                         -0.014844
# 8452                         -0.177683                          0.025531
# 8453                         -0.028717                         -0.036434
#
#       Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                            0.061376                         0.104751
# 1                            0.048356                         0.082538
# 2                            0.023594                         0.045900
# 3                            0.124473                         0.153696
# 4                            0.038483                         0.040109
# ...                               ...                              ...
# 8449                        -0.099438                        -0.107922
# 8450                        -0.036355                        -0.064550
# 8451                        -0.015225                        -0.025579
# 8452                        -0.251917                        -0.232001
# 8453                        -0.068563                        -0.041988
#
# [8454 rows x 1794 columns]
