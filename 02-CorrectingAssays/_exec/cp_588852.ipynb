# %% [markdown]
# ### Correction of the ML-Ready Cell-Painting Data Sets
# #### Prerequisite
# This notebook is part of the master thesis of Luis Vollmers. It uses the cell paintin data set of Bray et al. and the goal of the project is to predict pubchem assay data. Originally this notebook was concerned with pubchem AID 1030 but this might be subject to change.
# #### Introduction
# The datasets generated in ml_ready of step 01 comprise several mistakes that have been made and that need to be corrected within this jupyter notebook. Mostly, the compounds listed in the rows of the ML-ready dataframes are not unique, due to a misunderstanding stemming from the Bray et al Cell-Painting paper. It was stated that the Metadata_broad_sample is a unique identifier which was found to be wrong. Identical compounds which were used in different concentrations and/or on different well-plates were assigned different Metadata_broad_sample values. This needs to be corrected as well as the averaging over the different column values. In the data columns, the cell painting features are listed and so far the algorithm just kept the first concentration and took the average of the respective multiplicates. The correct way of doing it however is to check how many concentrations are present and then take the median of the concentration that is most frequent which is done by this jupyter notebook.
# #### Summary of the steps in this notebook
# 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# 2. Reintroduce the center median data into the pubchem df
# 3. Treat the multi-concentration Compounds adequately
# 4. Export the output

# %%
import pandas as pd
pd.set_option("max_rows",1200)

# %% [markdown]
# #### 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# - Inputs are taken from the directory for step 1 of the pubchem assays and from the preprocessing directory
# - the data from cp_1030 is erroneous but the meta data is needed for the overlap with the center median data
# - therefore filter the df for the metadata

# %%
# load the data into RAM 'cp_1030' can be used as a variable for a bash script
dataset_path='../../01-FilteringAssays/ml_ready/cp_588852.csv'
df = pd.read_csv(dataset_path, index_col=0).drop(axis=1,columns=['Unnamed: 0.1'])

# read the cell-painting data into RAM
cp = pd.read_csv('../../../preprocessing/cp_center_median.csv', index_col=0)

# define the meta cols of the pubchem assays that are relevant and filter the df 
meta_cols = ['Metadata_broad_sample','PUBCHEM_ACTIVITY_OUTCOME', 'PUBCHEM_ACTIVITY_SCORE']
df = df.loc[:,meta_cols]

# %% [markdown]
# #### 2. Reintroduce the Center Median Data into the Pubchem DF
# - the common column is Metadata_broad_sample which was responsible for the errors in the first place
# - it is actually the only identifier column that is left in the ML-ready df
# - the inner merge makes sure that only rows are kept that can be found in both dataframes

# %%
# merge the cp and the assay data on the common column
merged = pd.merge(left=cp, right=df, on='Metadata_broad_sample', how='inner')

# %%
# this cell calculates the number of rows expected from the final dataframe
multi_list = []
concs_list = merged.CAN_SMILES.value_counts().to_list()

for i in concs_list:
    if i > 1:
        multi_list.append(i)
        
merged.shape[0]-sum(multi_list)+len(multi_list)
# Out:
# 8795

# %% [markdown]
# #### 3. Treat the multi-concentration Compounds adequately
# - this step is the only one that needs to be conducted manually
# - first look at the multi conc compounds and determine how to treat them
# - in this case the concentrations that are less frequent are dropped and the remaining ones are calculated into median
# - for that purpose the merged DF is split into data and meta columns and only the data columns are treated accordingly
# - the groupby method is used to calculate the compound wise median
# - the single concentrations are already calculated so only the multi concs are actually computed herein

# %%
# have a look at the multi concentration compounds and figure out how to treat them
multi_merged = merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']]

for i,j in multi_merged.groupby("CAN_SMILES"):
    print("{}\n{}\n\n".format(i,j.Metadata_mmoles_per_liter.value_counts()))
# Out:
# CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1
# 2.120111    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.989704    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@@H]1C
# 5.062167    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 5.095349    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.225374    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 4.922948    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C
# 5.032085    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 4.981522    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.104492    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CNC[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.012874    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CNC[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 4.973595    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 3.768872    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1
# 5.08034    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@H](C)CO)C[C@H]2C)cc1
# 5.03069    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccc(S(=O)(=O)N(C)C[C@H]2OCc3cn(nn3)CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1
# 5.066855    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1cccc(S(=O)(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@@H]2C)c1
# 5.019124    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1cccc(S(=O)(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)c1
# 4.970379    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1cccc(S(=O)(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@H]2C)c1
# 5.063846    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.953088    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 4.947376    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1CN(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.018698    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 4.949222    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.098416    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.021188    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 4.976038    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)CCC(F)(F)F)OCc2cnnn2CCCC1=O
# 5.048502    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Cc2ccccc2)OCc2cnnn2CCCC1=O
# 5.01477    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)NC2CCCCC2)OCc2cnnn2CCCC1=O
# 5.246041    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2ccc(N3CCCCC3)cc2)OCc2cnnn2CCCC1=O
# 5.089334    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2cccc(Oc3ccccn3)c2)OCc2cnnn2CCCC1=O
# 5.078717    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Oc2cccc3ccccc23)OCc2cnnn2CCCC1=O
# 4.958227    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2cc(-c3ccccc3)on2)OCc2cnnn2CCCC1=O
# 4.946928    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc(N3CCN(C)CC3)cc2)OCc2cnnn2CCCC1=O
# 5.027187    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc3ccn(C)c3c2)OCc2cnnn2CCCC1=O
# 5.100838    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccncc2)OCc2cnnn2CCCC1=O
# 5.025291    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)S(=O)(=O)c2ccc3ccccc3c2)OCc2cnnn2CCCC1=O
# 4.985317    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)CCC(F)(F)F)OCc2cnnn2CCCC1=O
# 5.089254    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2ccccc2)OCc2cnnn2CCCC1=O
# 4.998222    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)NC2CCCCC2)OCc2cnnn2CCCC1=O
# 5.139115    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccc(N3CCCCC3)cc2)OCc2cnnn2CCCC1=O
# 5.048075    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2cccc(Oc3ccccn3)c2)OCc2cnnn2CCCC1=O
# 5.061389    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc(N3CCOCC3)c2)OCc2cnnn2CCCC1=O
# 5.023607    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc3ccccc23)OCc2cnnn2CCCC1=O
# 4.974357    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2cc(-c3ccccc3)on2)OCc2cn(nn2)CCCC1=O
# 5.056806    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc(N3CCN(C)CC3)cc2)OCc2cnnn2CCCC1=O
# 5.036903    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3ccn(C)c3c2)OCc2cn(nn2)CCCC1=O
# 5.064341    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3ccn(C)c3c2)OCc2cnnn2CCCC1=O
# 4.918819    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc2)OCc2cnnn2CCCC1=O
# 4.925582    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc(C(F)(F)F)cc2)OCc2cnnn2CCCC1=O
# 5.244719    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3c(c2)OCO3)OCc2cnnn2CCCC1=O
# 5.056964    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3cccnc3c2)OCc2cnnn2CCCC1=O
# 5.102371    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccc3c2OCCCO3)OCc2cnnn2CCCC1=O
# 5.264151    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccccc2C(F)(F)F)OCc2cnnn2CCCC1=O
# 5.056832    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccnc2)OCc2cnnn2CCCC1=O
# 5.283297    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(=O)(=O)c2ccc3ccccc3c2)OCc2cn(nn2)CCCC1=O
# 5.042229    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(=O)(=O)c2ccc3ccccc3c2)OCc2cnnn2CCCC1=O
# 5.033938    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(=O)(=O)c2ccccc2F)OCc2cn(nn2)CCCC1=O
# 5.006231    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(C)(=O)=O)OCc2cnnn2CCCC1=O
# 5.076955    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)NC1CCCCC1
# 4.900951    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccc2c(c1)OCO2
# 5.114419    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccccc1
# 4.961919    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccccc1C(F)(F)F
# 4.609011    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1
# 4.968168    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Oc1ccc2ccccc2c1
# 5.071692    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.13117    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.107174    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.003374    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 5.124577    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.089886    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)S(=O)(=O)c1ccccc1F
# 4.931146    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)S(C)(=O)=O
# 5.001828    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)CCC(F)(F)F
# 4.924469    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Cc1ccccc1
# 5.006586    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)NC1CCCCC1
# 5.090647    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.050268    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1
# 5.014762    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.11385    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.071386    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.026029    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 4.984975    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Cc1ccccc1
# 4.968832    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.031898    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.064662    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.042846    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.02388    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 5.095853    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c
=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@@H]2C)cc1
# 4.99429    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1
# 5.022274    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1
# 5.079624    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1
# 5.008339    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1
# 5.014177    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.799525    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C
# 4.945691    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.031205    1
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3.580507    1
# Name: Metadata_mmoles_per_liter, dtype: int64

# %%
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1')].index)
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1')].index)
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C(C)(C)[C@@H]5CC[C@@]4(C)[C@]3(C)CC[C@@]2(C(=O)O)CC[C@H]1C')].index)
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21')].index)

merged.shape[0]
# Out:
# 9832

# %%
# Quality Control step that makes sure only the relevant rows with the most concentrations are kept
merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']] # just needed as a one time lookup
# Out:
#                                              CAN_SMILES  \
# 8653              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8654              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8655              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8656              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8657              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8658              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8659              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8660              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8661  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8662  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8663  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8664  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8665  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8666  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8667  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8668  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8669                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8670                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8671                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8672                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8673                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8674                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8675                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8676                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8677  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8678  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8679  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8680  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8681  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8682  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8683  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8684  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8685  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8686  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8687  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8688  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8689  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8690  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8691  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8692  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8693  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8694  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8695  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8696  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 8697  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 8698  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 8699  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 8700  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 8701  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8702  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8703  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8704  COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O...
# 8705  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 8706  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 8707  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 8708  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 8709  COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C
=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O...
# 8986  COc1cccc(S(=O)(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O...
# 8987  COc1cccc(S(=O)(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O...
# 8988  COc1cccc(S(=O)(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O...
# 8989  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8990  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8991  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8992  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8993  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8994  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8995  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8996  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8997  Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)...
# 8998  Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)...
# 8999  Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)...
# 9000  Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)...
# 9001  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9002  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9003  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9004  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9005  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9006  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9007  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9008  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9009  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9010  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9011  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9012  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9013  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9014  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9015  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9016  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9017  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N...
# 9018  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N...
# 9019  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N...
# 9020  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N...
# 9021  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9022  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9023  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9024  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9025  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(C)(=O)=O)O...
# 9026  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(C)(=O)=O)O...
# 9027  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(C)(=O)=O)O...
# 9028  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(C)(=O)=O)O...
# 9029  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9030  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9031  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9032  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9033  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9034  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9035  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9036  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9037  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc(...
# 9038  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc(...
# 9039  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc(...
# 9040  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc(...
# 9041  COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=...
# 9042  COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=...
# 9043  COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=...
# 9044  COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=...
# 9045  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9046  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9047  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9048  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9049  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccc(...
# 9050  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccc(...
# 9051  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccc(...
# 9052  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccc(...
# 9053  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2cccc...
# 9054  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2cccc...
# 9055  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2cccc...
# 9056  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2cccc...
# 9057  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9058  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9059  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9060  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9061  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9062  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9063  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9064  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9065  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9066  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9067  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9068  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9069  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9070  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9071  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9072  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9073  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccccc2C(F...
# 9074  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccccc2C(F...
# 9075  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccccc2C(F...
# 9076  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2ccc...
# 9077  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2ccc...
# 9078  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2ccc...
# 9079  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccnc2)OC...
# 9080  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccnc2)OC...
# 9081  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccnc2)OC...
# 9082  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9083  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9084  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9085  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3c...
# 9086  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3c...
# 9087  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3c...
# 9088  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]...
# 9089  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]...
# 9090  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]...
# 9091  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9092  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9093  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9094  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9095  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9096  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9097  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)NC2CCCC...
# 9098  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)NC2CCCC...
# 9099  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)NC2CCCC...
# 9100  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9101  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9102  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9103  Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C...
# 9104  Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C...
# 9105  Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C...
# 9106  CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H...
# 9107  CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H...
# 9108  CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H...
# 9109  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9110  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9111  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9112  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9113  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9114  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9115  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3cccnc...
# 9116  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3cccnc...
# 9117  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3cccnc...
# 9118  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9119  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9120  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9121  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O...
# 9122  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O...
# 9123  Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O...
# 9124  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9125  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9126  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9127  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9128  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9129  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9130  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9131  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9132  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9133  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc...
# 9134  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc...
# 9135  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc...
# 9136  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9137  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9138  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9139  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9140  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9141  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9142  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3c(c2)...
# 9143  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3c(c2)...
# 9144  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3c(c2)...
# 9145  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9146  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9147  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9148  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9149  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9150  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9151  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)NC2CCC...
# 9152  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)NC2CCC...
# 9153  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)NC2CCC...
# 9154  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc(N...
# 9155  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc(N...
# 9156  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc(N...
# 9157  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)CCC(F)...
# 9158  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)CCC(F)...
# 9159  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)CCC(F)...
# 9160  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9161  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9162  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9163  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9164  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9165  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9166  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9167  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9168  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9169  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9170  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9171  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9172  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9173  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9174  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9175  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc(C(F)(...
# 9176  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc(C(F)(...
# 9177  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc(C(F)(...
# 9178  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9179  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9180  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9181  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc3...
# 9182  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc3...
# 9183  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc3...
# 9184  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9185  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9186  Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@...
# 9187  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)CCC(F)(...
# 9188  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)CCC(F)(...
# 9189  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)CCC(F)(...
# 9190  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9191  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9192  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9193  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9194  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9195  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9196  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9197  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9198  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9199  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2cccc...
# 9200  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2cccc...
# 9201  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2cccc...
# 9202  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9203  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9204  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9205  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccc3c2OC...
# 9206  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccc3c2OC...
# 9207  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccc3c2OC...
# 9208  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9209  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9210  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9211  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]...
# 9212  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]...
# 9213  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]...
# 9214  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9215  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9216  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9217  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9218  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9219  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 9220  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9221  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9222  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9223  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9224  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9225  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9226  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 9227  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 9228  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 9229  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9230  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9231  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9247  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9248  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9249  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9250  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]...
# 9251  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9252  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9253  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9254  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H...
# 9255  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9256  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9257  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9258  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9259  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc...
# 9260  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc...
# 9261  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc...
# 9262  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc...
# 9263  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9264  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9265  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9266  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9267  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9268  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9269  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9270  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9271  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9272  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9273  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9274  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN...
# 9275  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Oc2ccc...
# 9276  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Oc2ccc...
# 9277  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Oc2ccc...
# 9278  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Oc2ccc...
# 9279  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9280  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9281  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9282  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9283  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9284  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9285  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9286  C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 9287  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 9288  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 9289  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 9290  C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc...
# 9291  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9292  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9293  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9294  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1...
# 9295   CNC[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1
C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9470  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 9471  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 9472  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 9473  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 9474  CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C...
# 9475  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9476  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9477  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9478  CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([...
# 9479  CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H...
# ...
# 9377                   4.952672
# 9378                   4.952672
# 9379                   5.141794
# 9380                   5.141794
# 9381                   5.141794
# 9382                   5.141794
# 9383                   5.061389
# 9384                   5.061389
# 9385                   5.061389
# 9386                   5.061389
# 9387                   5.239790
# 9388                   5.239790
# 9389                   5.239790
# 9390                   5.239790
# 9391                   5.071692
# 9392                   5.071692
# 9393                   5.071692
# 9394                   5.071692
# 9395                   4.976973
# 9396                   4.976973
# 9397                   4.976973
# 9398                   4.976973
# 9399                   5.089254
# 9400                   5.089254
# 9401                   5.089254
# 9402                   5.089254
# 9403                   4.924469
# 9404                   4.924469
# 9405                   4.924469
# 9406                   4.924469
# 9407                   5.048502
# 9408                   5.048502
# 9409                   5.048502
# 9410                   5.048502
# 9411                   4.930435
# 9412                   4.930435
# 9413                   4.930435
# 9414                   4.930435
# 9415                   5.123405
# 9416                   5.123405
# 9417                   5.123405
# 9418                   5.123405
# 9419                   4.850914
# 9420                   4.850914
# 9421                   4.850914
# 9422                   4.850914
# 9423                   5.004353
# 9424                   5.004353
# 9425                   5.004353
# 9426                   5.004353
# 9427                   4.880398
# 9428                   4.880398
# 9429                   4.880398
# 9430                   4.880398
# 9431                   5.139115
# 9432                   5.139115
# 9433                   5.139115
# 9434                   5.139115
# 9435                   5.225993
# 9436                   5.225993
# 9437                   5.225993
# 9438                   5.225993
# 9439                   5.090647
# 9440                   5.090647
# 9441                   5.090647
# 9442                   5.090647
# 9443                   5.246041
# 9444                   5.246041
# 9445                   5.246041
# 9446                   5.246041
# 9447                   4.978727
# 9448                   4.978727
# 9449                   4.978727
# 9450                   4.978727
# 9451                   5.258519
# 9452                   5.258519
# 9453                   5.258519
# 9454                   5.258519
# 9455                   5.096569
# 9456                   5.096569
# 9457                   5.096569
# 9458                   5.096569
# 9459                   5.264151
# 9460                   5.264151
# 9461                   5.264151
# 9462                   5.264151
# 9463                   5.031508
# 9464                   5.031508
# 9465                   5.031508
# 9466                   5.031508
# 9467                   5.124180
# 9468                   5.124180
# 9469                   5.124180
# 9470                   5.124180
# 9471                   5.062843
# 9472                   5.062843
# 9473                   5.062843
# 9474                   5.062843
# 9475                   4.989704
# 9476                   4.989704
# 9477                   4.989704
# 9478                   4.989704
# 9479                   4.962919
# 9480                   4.962919
# 9481                   4.962919
# 9482                   4.962919
# 9483                   4.837163
# 9484                   4.837163
# 9485                   4.837163
# 9486                   4.837163
# 9487                   5.062167
# 9488                   5.062167
# 9489                   5.062167
# 9490                   5.062167
# 9491                   5.104492
# 9492                   5.104492
# 9493                   5.104492
# 9494                   5.104492
# 9495                   5.225374
# 9496                   5.225374
# 9497                   5.225374
# 9498                   5.225374
# 9499                   5.095349
# 9500                   5.095349
# 9501                   5.095349
# 9502                   5.095349
# 9503                   4.893264
# 9504                   4.893264
# 9505                   4.893264
# 9506                   4.893264
# 9507                   5.036903
# 9508                   5.036903
# 9509                   5.036903
# 9510                   5.036903
# 9511                   5.040004
# 9512                   5.040004
# 9513                   5.040004
# 9514                   5.040004
# 9515                   5.014960
# 9516                   5.014960
# 9517                   5.014960
# 9518                   5.014960
# 9519                   5.007248
# 9520                   5.007248
# 9521                   5.007248
# 9522                   5.007248
# 9523                   5.052025
# 9524                   5.052025
# 9525                   5.052025
# 9526                   5.052025
# 9527                   5.184310
# 9528                   5.184310
# 9529                   5.184310
# 9530                   5.184310
# 9531                   5.031349
# 9532                   5.031349
# 9533                   5.031349
# 9534                   5.031349
# 9535                   4.932734
# 9536                   4.932734
# 9537                   4.932734
# 9538                   4.932734
# 9539                   5.031989
# 9540                   5.031989
# 9541                   5.031989
# 9542                   5.031989
# 9543                   5.114838
# 9544                   5.114838
# 9545                   5.114838
# 9546                   5.114838
# 9547                   5.001650
# 9548                   5.001650
# 9549                   5.001650
# 9550                   5.001650
# 9551                   5.195511
# 9552                   5.195511
# 9553                   5.195511
# 9554                   5.195511
# 9555                   5.056964
# 9556                   5.056964
# 9557                   5.056964
# 9558                   5.056964
# 9559                   5.091180
# 9560                   5.091180
# 9561                   5.091180
# 9562                   5.091180
# 9563                   4.937611
# 9564                   4.937611
# 9565                   4.937611
# 9566                   4.937611
# 9567                   5.213841
# 9568                   5.213841
# 9569                   5.213841
# 9570                   5.213841
# 9571                   4.975108
# 9572                   4.975108
# 9573                   4.975108
# 9574                   4.975108
# 9575                   4.909627
# 9576                   4.909627
# 9577                   4.909627
# 9578                   4.909627
# 9579                   5.233043
# 9580                   5.233043
# 9581                   5.233043
# 9582                   5.233043
# 9583                   5.126058
# 9584                   5.126058
# 9585                   5.126058
# 9586                   5.126058
# 9587                   4.980771
# 9588                   4.980771
# 9589                   4.980771
# 9590                   4.980771
# 9591                   5.041802
# 9592                   5.041802
# 9593                   5.041802
# 9594                   5.041802
# 9595                   4.987231
# 9596                   4.987231
# 9597                   4.987231
# 9598                   4.987231
# 9599                   5.012009
# 9600                   5.012009
# 9601                   5.012009
# 9602                   5.012009
# 9603                   4.913217
# 9604                   4.913217
# 9605                   4.913217
# 9606                   4.913217
# 9607                   5.097054
# 9608                   5.097054
# 9609                   5.097054
# 9610                   5.097054
# 9611                   5.025684
# 9612                   5.025684
# 9750                   4.902670
# 9751                   4.933858
# 9752                   4.933858
# 9753                   4.933858
# 9754                   4.933858
# 9755                   5.161175
# 9756                   5.161175
# 9757                   5.161175
# 9758                   5.161175
# 9759                   4.983639
# 9760                   4.983639
# 9761                   4.983639
# 9762                   4.983639
# 9763                   5.066968
# 9764                   5.066968
# 9765                   5.066968
# 9766                   5.066968
# 9767                   4.882292
# 9768                   4.882292
# 9769                   4.882292
# 9770                   4.882292
# 9771                   5.236087
# 9772                   5.236087
# 9773                   5.236087
# 9774                   5.236087
# 9775                   5.002851
# 9776                   5.002851
# 9777                   5.002851
# 9778                   5.002851
# 9779                   4.897774
# 9780                   4.897774
# 9781                   4.897774
# 9782                   4.897774
# 9783                   4.875204
# 9784                   4.875204
# 9785                   4.875204
# 9786                   4.875204
# 9787                   5.189670
# 9788                   5.189670
# 9789                   5.189670
# 9790                   5.189670
# 9791                   5.224529
# 9792                   5.224529
# 9793                   5.224529
# 9794                   5.224529
# 9795                   5.178240
# 9796                   5.178240
# 9797                   5.178240
# 9798                   5.178240
# 9799                   5.107492
# 9800                   5.107492
# 9801                   5.107492
# 9802                   5.107492
# 9803                   4.609011
# 9804                   4.609011
# 9805                   4.609011
# 9806                   4.609011
# 9807                   5.175297
# 9808                   5.175297
# 9809                   5.175297
# 9810                   5.175297
# 9811                   5.009490
# 9812                   5.009490
# 9813                   5.009490
# 9814                   5.009490
# 9815                   4.885897
# 9816                   4.885897
# 9817                   4.885897
# 9818                   4.885897
# 9819                   4.939828
# 9820                   4.939828
# 9821                   4.939828
# 9822                   4.939828
# 9823                   5.049401
# 9824                   5.049401
# 9825                   5.049401
# 9826                   5.049401
# 9827                   5.043599
# 9828                   5.043599
# 9829                   5.043599
# 9830                   5.043599
# 9831                   5.080316
# 9832                   5.080316
# 9833                   5.080316
# 9834                   5.080316
# 9835                   4.925582
# 9836                   4.925582
# 9837                   4.925582
# 9838                   4.925582
# 9839                   5.025291
# 9840                   5.025291
# 9841                   5.025291
# 9842                   5.025291
# 9843                   5.113564
# 9844                   5.113564
# 9845                   5.113564
# 9846                   5.113564

# %%
# define a list of the all columns of the merged data frame
all_cols = merged.columns.to_list()
# redefine meta columns with the meta information of the cell painting assay
meta_cols = ['CAN_SMILES','CPD_SMILES','Metadata_broad_sample','Metadata_Plate_Map_Name','Metadata_ASSAY_WELL_ROLE','Metadata_Plate','SINGLE_CONC','PUBCHEM_ACTIVITY_SCORE','PUBCHEM_ACTIVITY_OUTCOME']

# %%
# data cols are basically all columns without the meta data. hence the forloop that removes those from data_cols
data_cols = all_cols
for item in meta_cols:
    data_cols.remove(item)
    
# afterwards the 'CAN_SMILES' column is inserted at the first position
data_cols.insert(0,'CAN_SMILES')

# %%
# the merged data frame is split into two dataframes containing meta and raw data information
merged_data = merged.loc[:,data_cols]
merged_meta = merged.loc[:,meta_cols]

# %%
# this command takes the compound wise median of the data
merged_data = merged_data.groupby('CAN_SMILES').median().reset_index()

# %% [markdown]
# #### 4. Export the Output
# - as a last step the only thing that needs to be done is to merge the meta and data columns back into one DF
# - a bit of a clean up needs to be done since the merge command creates suplicates, which can be safely deleted
# - output in csv format named according to the pubchem AID

# %%
# the median data is merged back with the meta data
merged = pd.merge(left=merged_meta, right=merged_data, on='CAN_SMILES', how='left')

# %%
# merging generally keeps all rows in both frames so that duplicates are generated, which get hereby deleted
merged = merged.drop_duplicates(subset='CAN_SMILES')

# %%
merged.to_csv('../_output/cp_588852.csv',index=False)

# %%
pd.read_csv('../_output/cp_588852.csv') # only uncomment for quality control purposes, i.e. visual conformation
# Out:
#                                              CAN_SMILES  \
# 0                              COc1cc(OC)c2ccc(=O)oc2c1
# 1                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 2          O=C(CCCN1CCC(O)(c2ccc(Br)cc2)CC1)c1ccc(F)cc1
# 3                      Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1
# 4     CCCCC1(COC(=O)CCC(=O)O)C(=O)N(c2ccccc2)N(c2ccc...
# ...                                                 ...
# 8790  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 8791  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 8792  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8793  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 8794  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
#
#                                              CPD_SMILES  \
# 0                              COc1cc(OC)c2ccc(=O)oc2c1
# 1                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 2          OC1(CCN(CCCC(=O)c2ccc(F)cc2)CC1)c1ccc(Br)cc1
# 3                      Cc1oncc1C(=O)Nc1ccc(cc1)C(F)(F)F
# 4     CCCCC1(COC(=O)CCC(O)=O)C(=O)N(N(C1=O)c1ccccc1)...
# ...                                                 ...
# 8790  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N(C[C...
# 8791  C[C@H](CO)N1C[C@H](C)[C@@H](CN(C)Cc2ccc3cccnc3...
# 8792  C[C@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc2...
# 8793  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 8794  C[C@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)c2ccncc2...
#
#        Metadata_broad_sample Metadata_Plate_Map_Name Metadata_ASSAY_WELL_ROLE  \
# 0     BRD-K78612426-001-02-6            H-BIOA-007-3                  treated
# 1     BRD-K78633253-001-01-2            H-BIOA-007-3                  treated
# 2     BRD-K78643075-001-03-3            H-BIOA-007-3                  treated
# 3     BRD-K78692225-001-11-2            H-BIOA-007-3                  treated
# 4     BRD-K78815826-001-04-7            H-BIOA-007-3                  treated
# ...                      ...                     ...                      ...
# 8790  BRD-K63778487-001-02-8            H-CBLD-003-4                  treated
# 8791  BRD-K16670438-001-02-5            H-CBLD-003-4                  treated
# 8792  BRD-K36882679-001-02-0            H-CBLD-003-4                  treated
# 8793  BRD-K19662956-001-02-1            H-CBLD-003-4                  treated
# 8794  BRD-K56183302-001-02-3            H-CBLD-003-4                  treated
#
#       Metadata_Plate  SINGLE_CONC  PUBCHEM_ACTIVITY_SCORE  \
# 0              24278         True                     0.0
# 1              24278         True                     0.0
# 2              24278         True                     0.0
# 3              24278         True                     0.0
# 4              24278         True                     0.0
# ...              ...          ...                     ...
# 8790           24740        False                     0.0
# 8791           24740        False                     0.0
# 8792           24740        False                     0.0
# 8793           24740        False                    12.0
# 8794           24740        False                     0.0
#
#      PUBCHEM_ACTIVITY_OUTCOME  Metadata_mmoles_per_liter  ...  \
# 0                    Inactive                   5.000000  ...
# 1                    Inactive                   5.000000  ...
# 2                    Inactive                   2.379167  ...
# 3                    Inactive                   5.000000  ...
# 4                    Inactive                   5.000000  ...
# ...                       ...                        ...  ...
# 8790                 Inactive                   5.062167  ...
# 8791                 Inactive                   5.113747  ...
# 8792                 Inactive                   5.049401  ...
# 8793                 Inactive                   5.025291  ...
# 8794                 Inactive                   5.043599  ...
#
#       Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                           -0.061549                        -0.133824
# 1                            0.098785                        -0.029717
# 2                            0.208695                        -0.024429
# 3                            0.078186                        -0.005418
# 4                           -0.049773                        -0.120946
# ...                               ...                              ...
# 8790                        -0.107988                        -0.067696
# 8791                        -0.271176                        -0.018774
# 8792                         0.022377                        -0.033583
# 8793                        -0.049191                        -0.046927
# 8794                         0.017946                        -0.076074
#
#       Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                          -0.130796                       -0.131496
# 1                          -0.036163                       -0.049478
# 2                          -0.044756                       -0.048945
# 3                          -0.038088                       -0.036953
# 4                          -0.057446                       -0.074382
# ...                              ...                             ...
# 8790                       -0.106654                       -0.078256
# 8791                       -0.137886                       -0.113983
# 8792                        0.021928                        0.004868
# 8793                       -0.009726                       -0.001119
# 8794                       -0.080742                       -0.064154
#
#       Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                             -0.153068                         -0.156526
# 1                             -0.122305                         -0.091394
# 2                             -0.091941                         -0.096263
# 3                             -0.075759                         -0.110328
# 4                             -0.102800                         -0.090232
# ...                                 ...                               ...
# 8790                          -0.038353                         -0.034741
# 8791                          -0.061528                         -0.082561
# 8792                           0.013618                          0.035613
# 8793                          -0.044611                         -0.062832
# 8794                          -0.066689                         -0.073823
#
#       Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                            -0.125545                          0.107378
# 1                            -0.115040                          0.200919
# 2                            -0.109370                          0.053506
# 3                            -0.092795                          0.107877
# 4                            -0.095308                          0.124821
# ...                                ...                               ...
# 8790                         -0.035673                         -0.004637
# 8791                         -0.073975                         -0.117175
# 8792                          0.017948                          0.050071
# 8793                         -0.094449                          0.034307
# 8794                         -0.061546                         -0.022567
#
#       Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                            0.023594                         0.045900
# 1                            0.124473                         0.153696
# 2                            0.038483                         0.040109
# 3                            0.034836                         0.063032
# 4                            0.014721                         0.040721
# ...                               ...                              ...
# 8790                        -0.003541                        -0.009770
# 8791                        -0.100076                        -0.087587
# 8792                         0.026995                         0.040520
# 8793                         0.006336                         0.011479
# 8794                        -0.038925                        -0.044059
#
# [8795 rows x 1794 columns]
