# %% [markdown]
# ### Correction of the ML-Ready Cell-Painting Data Sets
# #### Prerequisite
# This notebook is part of the master thesis of Luis Vollmers. It uses the cell paintin data set of Bray et al. and the goal of the project is to predict pubchem assay data. Originally this notebook was concerned with pubchem AID 1030 but this might be subject to change.
# #### Introduction
# The datasets generated in ml_ready of step 01 comprise several mistakes that have been made and that need to be corrected within this jupyter notebook. Mostly, the compounds listed in the rows of the ML-ready dataframes are not unique, due to a misunderstanding stemming from the Bray et al Cell-Painting paper. It was stated that the Metadata_broad_sample is a unique identifier which was found to be wrong. Identical compounds which were used in different concentrations and/or on different well-plates were assigned different Metadata_broad_sample values. This needs to be corrected as well as the averaging over the different column values. In the data columns, the cell painting features are listed and so far the algorithm just kept the first concentration and took the average of the respective multiplicates. The correct way of doing it however is to check how many concentrations are present and then take the median of the concentration that is most frequent which is done by this jupyter notebook.
# #### Summary of the steps in this notebook
# 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# 2. Reintroduce the center median data into the pubchem df
# 3. Treat the multi-concentration Compounds adequately
# 4. Export the output

# %%
import pandas as pd

# %% [markdown]
# #### 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# - Inputs are taken from the directory for step 1 of the pubchem assays and from the preprocessing directory
# - the data from cp_1030 is erroneous but the meta data is needed for the overlap with the center median data
# - therefore filter the df for the metadata

# %%
# load the data into RAM 'cp_1030' can be used as a variable for a bash script
dataset_path='../../01-FilteringAssays/ml_ready/cp_485313.csv'
df = pd.read_csv(dataset_path, index_col=0).drop(axis=1,columns=['Unnamed: 0.1'])

# read the cell-painting data into RAM
cp = pd.read_csv('../../../preprocessing/cp_center_median.csv', index_col=0)

# define the meta cols of the pubchem assays that are relevant and filter the df 
meta_cols = ['Metadata_broad_sample','PUBCHEM_ACTIVITY_OUTCOME', 'PUBCHEM_ACTIVITY_SCORE']
df = df.loc[:,meta_cols]

# %% [markdown]
# #### 2. Reintroduce the Center Median Data into the Pubchem DF
# - the common column is Metadata_broad_sample which was responsible for the errors in the first place
# - it is actually the only identifier column that is left in the ML-ready df
# - the inner merge makes sure that only rows are kept that can be found in both dataframes

# %%
# merge the cp and the assay data on the common column
merged = pd.merge(left=cp, right=df, on='Metadata_broad_sample', how='inner')

# %%
# this cell calculates the number of rows expected from the final dataframe
multi_list = []
concs_list = merged.CAN_SMILES.value_counts().to_list()

for i in concs_list:
    if i > 1:
        multi_list.append(i)
        
merged.shape[0]-sum(multi_list)+len(multi_list)
# Out:
# 7824

# %% [markdown]
# #### 3. Treat the multi-concentration Compounds adequately
# - this step is the only one that needs to be conducted manually
# - first look at the multi conc compounds and determine how to treat them
# - in this case the concentrations that are less frequent are dropped and the remaining ones are calculated into median
# - for that purpose the merged DF is split into data and meta columns and only the data columns are treated accordingly
# - the groupby method is used to calculate the compound wise median
# - the single concentrations are already calculated so only the multi concs are actually computed herein

# %%
# have a look at the multi concentration compounds and figure out how to treat them
merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']] # only uncomment if you havent checked for said compounds yet
# Out:
#                                              CAN_SMILES  \
# 7965              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7966              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7967              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7968              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7969              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7970              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7971              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7972              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7973  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7974  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7975  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7976  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7977  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7978  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7979  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7980  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7981  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7982  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7983  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7984  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7985  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7986  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7987  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7988  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7989                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7990                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7991                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7992                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7993                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7994                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7995                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7996                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7997  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 7998  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 7999  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8000  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8001  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8002  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8003  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8004  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8005  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8006  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8007  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8008  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8009  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8010  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8011  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8012  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 8013  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8014  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8015  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8016  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8017                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8018                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8019                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 8020              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8021              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8022              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 8023              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
#
#       Metadata_mmoles_per_liter
# 7965                   3.580507
# 7966                   3.580507
# 7967                   3.580507
# 7968                   3.580507
# 7969                   3.580507
# 7970                   3.580507
# 7971                   3.580507
# 7972                   3.580507
# 7973                   2.120111
# 7974                   2.120111
# 7975                   2.120111
# 7976                   2.120111
# 7977                   2.120111
# 7978                   2.120111
# 7979                   2.120111
# 7980                   2.120111
# 7981                   2.120111
# 7982                   2.120111
# 7983                   2.120111
# 7984                   2.120111
# 7985                   2.120111
# 7986                   2.120111
# 7987                   2.120111
# 7988                   2.120111
# 7989                   3.768872
# 7990                   3.768872
# 7991                   3.768872
# 7992                   3.768872
# 7993                   3.768872
# 7994                   3.768872
# 7995                   3.768872
# 7996                   3.768872
# 7997                   2.189620
# 7998                   2.189620
# 7999                   2.189620
# 8000                   2.189620
# 8001                   2.189620
# 8002                   2.189620
# 8003                   2.189620
# 8004                   2.189620
# 8005                   5.000000
# 8006                   5.000000
# 8007                   5.000000
# 8008                   5.000000
# 8009                   5.000000
# 8010                   5.000000
# 8011                   5.000000
# 8012                   5.000000
# 8013                   5.000000
# 8014                   5.000000
# 8015                   5.000000
# 8016                   5.000000
# 8017                   5.000000
# 8018                   5.000000
# 8019                   5.000000
# 8020                   5.000000
# 8021                   5.000000
# 8022                   5.000000
# 8023                   5.000000

# %%
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0)].index)

# %%
# Quality Control step that makes sure only the relevant rows with the most concentrations are kept
merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']] # just needed as a one time lookup
# Out:
#                                              CAN_SMILES  \
# 7965              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7966              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7967              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7968              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7969              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7970              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7971              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7972              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7973  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7974  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7975  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7976  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7977  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7978  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7979  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7980  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7981  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7982  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7983  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7984  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7985  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7986  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7987  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7988  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7989                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7990                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7991                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7992                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7993                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7994                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7995                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7996                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7997  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 7998  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 7999  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8000  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8001  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8002  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8003  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
# 8004  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
#
#       Metadata_mmoles_per_liter
# 7965                   3.580507
# 7966                   3.580507
# 7967                   3.580507
# 7968                   3.580507
# 7969                   3.580507
# 7970                   3.580507
# 7971                   3.580507
# 7972                   3.580507
# 7973                   2.120111
# 7974                   2.120111
# 7975                   2.120111
# 7976                   2.120111
# 7977                   2.120111
# 7978                   2.120111
# 7979                   2.120111
# 7980                   2.120111
# 7981                   2.120111
# 7982                   2.120111
# 7983                   2.120111
# 7984                   2.120111
# 7985                   2.120111
# 7986                   2.120111
# 7987                   2.120111
# 7988                   2.120111
# 7989                   3.768872
# 7990                   3.768872
# 7991                   3.768872
# 7992                   3.768872
# 7993                   3.768872
# 7994                   3.768872
# 7995                   3.768872
# 7996                   3.768872
# 7997                   2.189620
# 7998                   2.189620
# 7999                   2.189620
# 8000                   2.189620
# 8001                   2.189620
# 8002                   2.189620
# 8003                   2.189620
# 8004                   2.189620

# %%
# define a list of the all columns of the merged data frame
all_cols = merged.columns.to_list()
# redefine meta columns with the meta information of the cell painting assay
meta_cols = ['CAN_SMILES','CPD_SMILES','Metadata_broad_sample','Metadata_Plate_Map_Name','Metadata_ASSAY_WELL_ROLE','Metadata_Plate','SINGLE_CONC','PUBCHEM_ACTIVITY_SCORE','PUBCHEM_ACTIVITY_OUTCOME']

# %%
# data cols are basically all columns without the meta data. hence the forloop that removes those from data_cols
data_cols = all_cols
for item in meta_cols:
    data_cols.remove(item)
    
# afterwards the 'CAN_SMILES' column is inserted at the first position
data_cols.insert(0,'CAN_SMILES')

# %%
# the merged data frame is split into two dataframes containing meta and raw data information
merged_data = merged.loc[:,data_cols]
merged_meta = merged.loc[:,meta_cols]

# %%
# this command takes the compound wise median of the data
merged_data = merged_data.groupby('CAN_SMILES').median().reset_index()

# %% [markdown]
# #### 4. Export the Output
# - as a last step the only thing that needs to be done is to merge the meta and data columns back into one DF
# - a bit of a clean up needs to be done since the merge command creates suplicates, which can be safely deleted
# - output in csv format named according to the pubchem AID

# %%
# the median data is merged back with the meta data
merged = pd.merge(left=merged_meta, right=merged_data, on='CAN_SMILES', how='left')

# %%
# merging generally keeps all rows in both frames so that duplicates are generated, which get hereby deleted
merged = merged.drop_duplicates(subset='CAN_SMILES')

# %%
merged.to_csv('../_output/cp_485313.csv',index=False)

# %%
pd.read_csv('../_output/cp_485313.csv') # only uncomment for quality control purposes, i.e. visual conformation
# Out:
#                                              CAN_SMILES  \
# 0                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 1          O=C(CCCN1CCC(O)(c2ccc(Br)cc2)CC1)c1ccc(F)cc1
# 2     CCCCC1(COC(=O)CCC(=O)O)C(=O)N(c2ccccc2)N(c2ccc...
# 3         COC(=O)c1c(C)[nH]c(C)c1C(=O)c1ccccc1Cc1ccccc1
# 4                     NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# ...                                                 ...
# 7819  CCOC(=O)c1c(C)oc2c1c(C(c1cccnc1)N1CCCCC1)c(O)c...
# 7820              Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 7821  CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...
# 7822                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7823  C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C...
#
#                                              CPD_SMILES  \
# 0                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 1          OC1(CCN(CCCC(=O)c2ccc(F)cc2)CC1)c1ccc(Br)cc1
# 2     CCCCC1(COC(=O)CCC(O)=O)C(=O)N(N(C1=O)c1ccccc1)...
# 3         COC(=O)c1c(C)[nH]c(C)c1C(=O)c1ccccc1Cc1ccccc1
# 4                     NC(=O)N\N=C\c1ccc(o1)[N+]([O-])=O
# ...                                                 ...
# 7819  CCOC(=O)c1c(C)oc2c1c(C(N1CCCCC1)c1cccnc1)c(O)c...
# 7820                Cn1c(cc(=O)c2ccccc12)-c1ccc2OCOc2c1
# 7821  CC(C)(C)c1ccc(cc1)C(O)CCCN1CCC(CC1)C(O)(c1cccc...
# 7822                   COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 7823  C[C@@H]1CC[C@@]2(CC[C@]3(C)C(=CC[C@@H]4[C@@]5(...
#
#        Metadata_broad_sample Metadata_Plate_Map_Name Metadata_ASSAY_WELL_ROLE  \
# 0     BRD-K78633253-001-01-2            H-BIOA-007-3                  treated
# 1     BRD-K78643075-001-03-3            H-BIOA-007-3                  treated
# 2     BRD-K78815826-001-04-7            H-BIOA-007-3                  treated
# 3     BRD-K78959463-001-02-5            H-BIOA-007-3                  treated
# 4     BRD-K79092138-001-04-5            H-BIOA-007-3                  treated
# ...                      ...                     ...                      ...
# 7819  BRD-A43050491-001-05-6       C-2113-01-D39-007                  treated
# 7820  BRD-K92683369-001-03-6            H-BIOA-007-3                  treated
# 7821  BRD-A06352418-001-03-6            H-BIOA-001-3                  treated
# 7822  BRD-K02764365-001-03-7            H-BIOA-003-3                  treated
# 7823  BRD-K68185022-001-02-3            H-BIOA-006-3                  treated
#
#       Metadata_Plate  SINGLE_CONC  PUBCHEM_ACTIVITY_SCORE  \
# 0              24278         True                     0.0
# 1              24278         True                     0.0
# 2              24278         True                     0.0
# 3              24278         True                     0.0
# 4              24278         True                     0.0
# ...              ...          ...                     ...
# 7819           26204         True                     0.0
# 7820           24278        False                     0.0
# 7821           24294        False                     0.0
# 7822           24305        False                     0.0
# 7823           24319        False                     0.0
#
#      PUBCHEM_ACTIVITY_OUTCOME  Metadata_mmoles_per_liter  ...  \
# 0                    Inactive                   5.000000  ...
# 1                    Inactive                   2.379167  ...
# 2                    Inactive                   5.000000  ...
# 3                    Inactive                   7.196170  ...
# 4                    Inactive                   5.000000  ...
# ...                       ...                        ...  ...
# 7819                 Inactive                   5.000000  ...
# 7820                 Inactive                   3.580507  ...
# 7821                 Inactive                   2.120111  ...
# 7822                 Inactive                   3.768872  ...
# 7823                 Inactive                   2.189620  ...
#
#       Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                            0.098785                        -0.029717
# 1                            0.208695                        -0.024429
# 2                           -0.049773                        -0.120946
# 3                            0.265760                         0.033455
# 4                            0.226008                        -0.048937
# ...                               ...                              ...
# 7819                         0.003111                         0.057371
# 7820                        -0.104311                         0.005627
# 7821                        -0.031586                         0.058706
# 7822                         0.027589                         0.329196
# 7823                        -0.074423                        -0.081100
#
#       Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                          -0.036163                       -0.049478
# 1                          -0.044756                       -0.048945
# 2                          -0.057446                       -0.074382
# 3                           0.009330                        0.016445
# 4                          -0.058689                       -0.064819
# ...                              ...                             ...
# 7819                        0.013895                        0.005887
# 7820                       -0.037484                       -0.027687
# 7821                        0.032472                        0.043662
# 7822                        0.292009                        0.379255
# 7823                       -0.062452                       -0.067922
#
#       Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                             -0.122305                         -0.091394
# 1                             -0.091941                         -0.096263
# 2                             -0.102800                         -0.090232
# 3                             -0.027188                         -0.029056
# 4                             -0.122381                         -0.118742
# ...                                 ...                               ...
# 7819                          -0.003589                          0.081811
# 7820                           0.023850                         -0.032037
# 7821                           0.006015                          0.019518
# 7822                          -0.098949                         -0.160635
# 7823                          -0.003202                         -0.051394
#
#       Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                            -0.115040                          0.200919
# 1                            -0.109370                          0.053506
# 2                            -0.095308                          0.124821
# 3                            -0.048618                          0.198655
# 4                            -0.121401                          0.144713
# ...                                ...                               ...
# 7819                          0.062094                         -0.116301
# 7820                          0.004835                         -0.078895
# 7821                          0.049757                         -0.014844
# 7822                         -0.177683                          0.025531
# 7823                         -0.028717                         -0.036434
#
#       Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                            0.124473                         0.153696
# 1                            0.038483                         0.040109
# 2                            0.014721                         0.040721
# 3                            0.115654                         0.141480
# 4                            0.059112                         0.086052
# ...                               ...                              ...
# 7819                        -0.099438                        -0.107922
# 7820                        -0.036355                        -0.064550
# 7821                        -0.015225                        -0.025579
# 7822                        -0.251917                        -0.232001
# 7823                        -0.068563                        -0.041988
#
# [7824 rows x 1794 columns]
