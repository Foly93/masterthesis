# %% [markdown]
# ### Correction of the ML-Ready Cell-Painting Data Sets
# #### Prerequisite
# This notebook is part of the master thesis of Luis Vollmers. It uses the cell paintin data set of Bray et al. and the goal of the project is to predict pubchem assay data. Originally this notebook was concerned with pubchem AID 1030 but this might be subject to change.
# #### Introduction
# The datasets generated in ml_ready of step 01 comprise several mistakes that have been made and that need to be corrected within this jupyter notebook. Mostly, the compounds listed in the rows of the ML-ready dataframes are not unique, due to a misunderstanding stemming from the Bray et al Cell-Painting paper. It was stated that the Metadata_broad_sample is a unique identifier which was found to be wrong. Identical compounds which were used in different concentrations and/or on different well-plates were assigned different Metadata_broad_sample values. This needs to be corrected as well as the averaging over the different column values. In the data columns, the cell painting features are listed and so far the algorithm just kept the first concentration and took the average of the respective multiplicates. The correct way of doing it however is to check how many concentrations are present and then take the median of the concentration that is most frequent which is done by this jupyter notebook.
# #### Summary of the steps in this notebook
# 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# 2. Reintroduce the center median data into the pubchem df
# 3. Treat the multi-concentration Compounds adequately
# 4. Export the output

# %%
import pandas as pd

# %% [markdown]
# #### 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# - Inputs are taken from the directory for step 1 of the pubchem assays and from the preprocessing directory
# - the data from cp_1030 is erroneous but the meta data is needed for the overlap with the center median data
# - therefore filter the df for the metadata

# %%
pd.set_option("max_rows",1200)
# load the data into RAM 'cp_1030' can be used as a variable for a bash script
dataset_path='../../01-FilteringAssays/ml_ready/cp_588458.csv'
df = pd.read_csv(dataset_path, index_col=0).drop(axis=1,columns=['Unnamed: 0.1'])

# read the cell-painting data into RAM
cp = pd.read_csv('../../../preprocessing/cp_center_median.csv', index_col=0)

# define the meta cols of the pubchem assays that are relevant and filter the df 
meta_cols = ['Metadata_broad_sample','PUBCHEM_ACTIVITY_OUTCOME', 'PUBCHEM_ACTIVITY_SCORE']
df = df.loc[:,meta_cols]

# %% [markdown]
# #### 2. Reintroduce the Center Median Data into the Pubchem DF
# - the common column is Metadata_broad_sample which was responsible for the errors in the first place
# - it is actually the only identifier column that is left in the ML-ready df
# - the inner merge makes sure that only rows are kept that can be found in both dataframes

# %%
# merge the cp and the assay data on the common column
merged = pd.merge(left=cp, right=df, on='Metadata_broad_sample', how='inner')

# %%
# this cell calculates the number of rows expected from the final dataframe
multi_list = []
concs_list = merged.CAN_SMILES.value_counts().to_list()

for i in concs_list:
    if i > 1:
        multi_list.append(i)
        
merged.shape[0]-sum(multi_list)+len(multi_list)
# Out:
# 8794

# %% [markdown]
# #### 3. Treat the multi-concentration Compounds adequately
# - this step is the only one that needs to be conducted manually
# - first look at the multi conc compounds and determine how to treat them
# - in this case the concentrations that are less frequent are dropped and the remaining ones are calculated into median
# - for that purpose the merged DF is split into data and meta columns and only the data columns are treated accordingly
# - the groupby method is used to calculate the compound wise median
# - the single concentrations are already calculated so only the multi concs are actually computed herein

# %%
multi_merged = merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']]

for i,j in multi_merged.groupby("CAN_SMILES"):
    print(i,j.Metadata_mmoles_per_liter)
# Out:
# CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1 8660    2.120111
# 8661    2.120111
# 8662    2.120111
# 8663    2.120111
# 8664    2.120111
# 8665    2.120111
# 8666    2.120111
# 8667    2.120111
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@H]1C 9159    5.010584
# 9160    5.010584
# 9161    5.010584
# 9474    4.989704
# 9475    4.989704
# 9476    4.989704
# 9477    4.989704
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@@H]1C 9216    5.021036
# 9217    5.021036
# 9218    5.021036
# 9486    5.062167
# 9487    5.062167
# 9488    5.062167
# 9489    5.062167
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C 9144    4.997005
# 9145    4.997005
# 9146    4.997005
# 9498    5.095349
# 9499    5.095349
# 9500    5.095349
# 9501    5.095349
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 9177    5.017207
# 9178    5.017207
# 9179    5.017207
# 9494    5.225374
# 9495    5.225374
# 9496    5.225374
# 9497    5.225374
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 8848    5.008734
# 8849    5.008734
# 8850    5.008734
# 8851    5.008734
# 9482    4.837163
# 9483    4.837163
# 9484    4.837163
# 9485    4.837163
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C 8704    5.001327
# 8705    5.001327
# 8706    5.001327
# 8707    5.001327
# 9470    5.062843
# 9471    5.062843
# 9472    5.062843
# 9473    5.062843
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 8944    5.000125
# 8945    5.000125
# 8946    5.000125
# 8947    5.000125
# 9478    4.962919
# 9479    4.962919
# 9480    4.962919
# 9481    4.962919
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 9105    5.026557
# 9106    5.026557
# 9107    5.026557
# 9490    5.104492
# 9491    5.104492
# 9492    5.104492
# 9493    5.104492
# Name: Metadata_mmoles_per_liter, dtype: float64
# CNC[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 8788    5.005743
# 8789    5.005743
# 8790    5.005743
# 8791    5.005743
# 9298    5.020006
# 9299    5.020006
# 9300    5.020006
# 9301    5.020006
# Name: Metadata_mmoles_per_liter, dtype: float64
# CNC[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 8820    5.03660
# 8821    5.03660
# 8822    5.03660
# 8823    5.03660
# 9294    4.91059
# 9295    4.91059
# 9296    4.91059
# 9297    4.91059
# Name: Metadata_mmoles_per_liter, dtype: float64
# COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1 8668    3.768872
# 8669    3.768872
# 8670    3.768872
# 8671    3.768872
# 8672    3.768872
# 8673    3.768872
# 8674    3.768872
# 8675    3.768872
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1 8892    5.011553
# 8893    5.011553
# 8894    5.011553
# 8895    5.011553
# 9714    5.149126
# 9715    5.149126
# 9716    5.149126
# 9717    5.149126
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc
# Name: Metadata_mmoles_per_liter, dtype: float64
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1 8716    5.021688
# 8717    5.021688
# 8718    5.021688
# 8719    5.021688
# 9254    5.124438
# 9255    5.124438
# 9256    5.124438
# 9257    5.124438
# Name: Metadata_mmoles_per_liter, dtype: float64
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12 8896    5.019240
# 8897    5.019240
# 8898    5.019240
# 8899    5.019240
# 9270    4.971403
# 9271    4.971403
# 9272    4.971403
# 9273    4.971403
# Name: Metadata_mmoles_per_liter, dtype: float64
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1 9111    5.023732
# 9112    5.023732
# 9113    5.023732
# 9338    5.172406
# 9339    5.172406
# 9340    5.172406
# 9341    5.172406
# Name: Metadata_mmoles_per_liter, dtype: float64
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1 8960    5.025691
# 8961    5.025691
# 8962    5.025691
# 8963    5.025691
# 9522    5.052025
# 9523    5.052025
# 9524    5.052025
# 9525    5.052025
# Name: Metadata_mmoles_per_liter, dtype: float64
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1 9008    5.022848
# 9009    5.022848
# 9010    5.022848
# 9011    5.022848
# 9746    4.902670
# 9747    4.902670
# 9748    4.902670
# 9749    4.902670
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@@H]2C)cc1 9102    5.000866
# 9103    5.000866
# 9104    5.000866
# 9642    4.994290
# 9643    4.994290
# 9644    4.994290
# 9645    4.994290
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1 8912    4.996151
# 8913    4.996151
# 8914    4.996151
# 8915    4.996151
# 9630    5.048398
# 9631    5.048398
# 9632    5.048398
# 9633    5.048398
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1 8900    5.003397
# 8901    5.003397
# 8902    5.003397
# 8903    5.003397
# 9638    5.155850
# 9639    5.155850
# 9640    5.155850
# 9641    5.155850
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1 9183    5.005205
# 9184    5.005205
# 9185    5.005205
# 9634    5.008339
# 9635    5.008339
# 9636    5.008339
# 9637    5.008339
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1 9068    5.015245
# 9069    5.015245
# 9070    5.015245
# 9071    5.015245
# 9626    5.013109
# 9627    5.013109
# 9628    5.013109
# 9629    5.013109
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C 8996    5.022708
# 8997    5.022708
# 8998    5.022708
# 8999    5.022708
# 9370    4.576343
# 9371    4.576343
# 9372    4.576343
# 9373    4.576343
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C 9120    5.014792
# 9121    5.014792
# 9122    5.014792
# 9614    4.945691
# 9615    4.945691
# 9616    4.945691
# 9617    4.945691
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 9016    5.013564
# 9017    5.013564
# 9018    5.013564
# 9019    5.013564
# 9366    5.048845
# 9367    5.048845
# 9368    5.048845
# 9369    5.048845
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21 8652    3.580507
# 8653    3.580507
# 8654    3.580507
# 8655    3.580507
# 8656    3.580507
# 8657    3.580507
# 8658    3.580507
# 8659    3.580507
# Name: Metadata_mmoles_per_liter, dtype: float64

# %%
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1')].index)
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1')].index)
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C(C)(C)[C@@H]5CC[C@@]4(C)[C@]3(C)CC[C@@]2(C(=O)O)CC[C@H]1C')].index)
merged = merged.drop(merged[(merged.SINGLE_CONC==False) & (merged.Metadata_mmoles_per_liter > 4.0) & (merged.CAN_SMILES=='Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21')].index)

merged.shape[0]
# Out:
# 9831

# %%
multi_merged = merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']]

for i,j in multi_merged.groupby("CAN_SMILES"):
    print(i,j.Metadata_mmoles_per_liter)
# Out:
# CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1 8660    2.120111
# 8661    2.120111
# 8662    2.120111
# 8663    2.120111
# 8664    2.120111
# 8665    2.120111
# 8666    2.120111
# 8667    2.120111
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@H]1C 9159    5.010584
# 9160    5.010584
# 9161    5.010584
# 9474    4.989704
# 9475    4.989704
# 9476    4.989704
# 9477    4.989704
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@@H]1C 9216    5.021036
# 9217    5.021036
# 9218    5.021036
# 9486    5.062167
# 9487    5.062167
# 9488    5.062167
# 9489    5.062167
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C 9144    4.997005
# 9145    4.997005
# 9146    4.997005
# 9498    5.095349
# 9499    5.095349
# 9500    5.095349
# 9501    5.095349
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 9177    5.017207
# 9178    5.017207
# 9179    5.017207
# 9494    5.225374
# 9495    5.225374
# 9496    5.225374
# 9497    5.225374
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 8848    5.008734
# 8849    5.008734
# 8850    5.008734
# 8851    5.008734
# 9482    4.837163
# 9483    4.837163
# 9484    4.837163
# 9485    4.837163
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C 8704    5.001327
# 8705    5.001327
# 8706    5.001327
# 8707    5.001327
# 9470    5.062843
# 9471    5.062843
# 9472    5.062843
# 9473    5.062843
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 8944    5.000125
# 8945    5.000125
# 8946    5.000125
# 8947    5.000125
# 9478    4.962919
# 9479    4.962919
# 9480    4.962919
# 9481    4.962919
# Name: Metadata_mmoles_per_liter, dtype: float64
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 9105    5.026557
# 9106    5.026557
# 9107    5.026557
# 9490    5.104492
# 9491    5.104492
# 9492    5.104492
# 9493    5.104492
# Name: Metadata_mmoles_per_liter, dtype: float64
# CNC[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 8788    5.005743
# 8789    5.005743
# 8790    5.005743
# 8791    5.005743
# 9298    5.020006
# 9299    5.020006
# 9300    5.020006
# 9301    5.020006
# Name: Metadata_mmoles_per_liter, dtype: float64
# CNC[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 8820    5.03660
# 8821    5.03660
# 8822    5.03660
# 8823    5.03660
# 9294    4.91059
# 9295    4.91059
# 9296    4.91059
# 9297    4.91059
# Name: Metadata_mmoles_per_liter, dtype: float64
# COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1 8668    3.768872
# 8669    3.768872
# 8670    3.768872
# 8671    3.768872
# 8672    3.768872
# 8673    3.768872
# 8674    3.768872
# 8675    3.768872
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1 8892    5.011553
# 8893    5.011553
# 8894    5.011553
# 8895    5.011553
# 9714    5.149126
# 9715    5.149126
# 9716    5.149126
# 9717    5.149126
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@H](C)CO)C[C@H]2C)cc1 9040    5.017851
# 9041    5.017851
# 9042    5.017851
# 9043    5.017851
# 9722    5.043529
# 9723    5.043529
# 9724    5.043529
# 9725    5.043529
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccc(S(=O)(=O)N(C)C[C@H]2OCc3cn(nn3)CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1 8916    5.034521
# 8917    5.034521
# 8918    5.034521
# 8919    5.034521
# 9718    5.099189
# 9719    5.099189
# 9720    5.099189
# 9721    5.099189
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1cccc(S(=O)(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@@H]2C)c1 8984    5.006259
# 8985    5.006259
# 8986    5.006259
# 8987    5.006259
# 9538    5.031989
# 9539    5.031989
# 9540    5.031989
# 9541    5.031989
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1cccc(S(=O)(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)c1 8784    5.008023
# 8785    5.008023
# 8786    5.008023
# 8787    5.008023
# 9534    4.932734
# 9535    4.932734
# 9536    4.932734
# 9537    4.932734
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1cccc(S(=O)(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@H]2C)c1 8872    5.012853
# 8873    5.012853
# 8874    5.012853
# 8875    5.012853
# 9542    5.114838
# 9543    5.114838
# 9544    5.114838
# 9545    5.114838
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C 8732    5.008402
# 8733    5.008402
# 8734    5.008402
# 8735    5.008402
# 9778    4.897774
# 9779    4.897774
# 9780    4.897774
# 9781    4.897774
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C 8708    5.019548
# 8709    5.019548
# 8710    5.019548
# 8711    5.019548
# 9782    4.875204
# 9783    4.875204
# 9784    4.875204
# 9785    4.875204
# Name: Metadata_mmoles_per_liter, dtype: float64
# COc1ccccc1CN(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1
=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1 8912    4.996151
# 8913    4.996151
# 8914    4.996151
# 8915    4.996151
# 9630    5.048398
# 9631    5.048398
# 9632    5.048398
# 9633    5.048398
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1 8900    5.003397
# 8901    5.003397
# 8902    5.003397
# 8903    5.003397
# 9638    5.155850
# 9639    5.155850
# 9640    5.155850
# 9641    5.155850
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1 9183    5.005205
# 9184    5.005205
# 9185    5.005205
# 9634    5.008339
# 9635    5.008339
# 9636    5.008339
# 9637    5.008339
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1 9068    5.015245
# 9069    5.015245
# 9070    5.015245
# 9071    5.015245
# 9626    5.013109
# 9627    5.013109
# 9628    5.013109
# 9629    5.013109
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C 8996    5.022708
# 8997    5.022708
# 8998    5.022708
# 8999    5.022708
# 9370    4.576343
# 9371    4.576343
# 9372    4.576343
# 9373    4.576343
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C 9120    5.014792
# 9121    5.014792
# 9122    5.014792
# 9614    4.945691
# 9615    4.945691
# 9616    4.945691
# 9617    4.945691
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C 9016    5.013564
# 9017    5.013564
# 9018    5.013564
# 9019    5.013564
# 9366    5.048845
# 9367    5.048845
# 9368    5.048845
# 9369    5.048845
# Name: Metadata_mmoles_per_liter, dtype: float64
# Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21 8652    3.580507
# 8653    3.580507
# 8654    3.580507
# 8655    3.580507
# 8656    3.580507
# 8657    3.580507
# 8658    3.580507
# 8659    3.580507
# Name: Metadata_mmoles_per_liter, dtype: float64

# %%
# define a list of the all columns of the merged data frame
all_cols = merged.columns.to_list()
# redefine meta columns with the meta information of the cell painting assay
meta_cols = ['CAN_SMILES','CPD_SMILES','Metadata_broad_sample','Metadata_Plate_Map_Name','Metadata_ASSAY_WELL_ROLE','Metadata_Plate','SINGLE_CONC','PUBCHEM_ACTIVITY_SCORE','PUBCHEM_ACTIVITY_OUTCOME']

# %%
# data cols are basically all columns without the meta data. hence the forloop that removes those from data_cols
data_cols = all_cols
for item in meta_cols:
    data_cols.remove(item)
    
# afterwards the 'CAN_SMILES' column is inserted at the first position
data_cols.insert(0,'CAN_SMILES')

# %%
# the merged data frame is split into two dataframes containing meta and raw data information
merged_data = merged.loc[:,data_cols]
merged_meta = merged.loc[:,meta_cols]

# %%
# this command takes the compound wise median of the data
merged_data = merged_data.groupby('CAN_SMILES').median().reset_index()

# %% [markdown]
# #### 4. Export the Output
# - as a last step the only thing that needs to be done is to merge the meta and data columns back into one DF
# - a bit of a clean up needs to be done since the merge command creates suplicates, which can be safely deleted
# - output in csv format named according to the pubchem AID

# %%
# the median data is merged back with the meta data
merged = pd.merge(left=merged_meta, right=merged_data, on='CAN_SMILES', how='left')

# %%
# merging generally keeps all rows in both frames so that duplicates are generated, which get hereby deleted
merged = merged.drop_duplicates(subset='CAN_SMILES')

# %%
merged.to_csv('../_output/cp_588458.csv',index=False)

# %%
pd.read_csv('../_output/cp_588458.csv') # only uncomment for quality control purposes, i.e. visual conformation
# Out:
#                                              CAN_SMILES  \
# 0                              COc1cc(OC)c2ccc(=O)oc2c1
# 1                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 2          O=C(CCCN1CCC(O)(c2ccc(Br)cc2)CC1)c1ccc(F)cc1
# 3                      Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1
# 4     CCCCC1(COC(=O)CCC(=O)O)C(=O)N(c2ccccc2)N(c2ccc...
# ...                                                 ...
# 8789  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@...
# 8790  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
# 8791  C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1C...
# 8792  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 8793  C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1C...
#
#                                              CPD_SMILES  \
# 0                              COc1cc(OC)c2ccc(=O)oc2c1
# 1                      COC(=O)c1ccccc1NC(=O)c1ccc(F)cc1
# 2          OC1(CCN(CCCC(=O)c2ccc(F)cc2)CC1)c1ccc(Br)cc1
# 3                      Cc1oncc1C(=O)Nc1ccc(cc1)C(F)(F)F
# 4     CCCCC1(COC(=O)CCC(O)=O)C(=O)N(N(C1=O)c1ccccc1)...
# ...                                                 ...
# 8789  CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N(C[C...
# 8790  C[C@H](CO)N1C[C@H](C)[C@@H](CN(C)Cc2ccc3cccnc3...
# 8791  C[C@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc2...
# 8792  C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccnc...
# 8793  C[C@H](CO)N1C[C@H](C)[C@@H](CN(C)C(=O)c2ccncc2...
#
#        Metadata_broad_sample Metadata_Plate_Map_Name Metadata_ASSAY_WELL_ROLE  \
# 0     BRD-K78612426-001-02-6            H-BIOA-007-3                  treated
# 1     BRD-K78633253-001-01-2            H-BIOA-007-3                  treated
# 2     BRD-K78643075-001-03-3            H-BIOA-007-3                  treated
# 3     BRD-K78692225-001-11-2            H-BIOA-007-3                  treated
# 4     BRD-K78815826-001-04-7            H-BIOA-007-3                  treated
# ...                      ...                     ...                      ...
# 8789  BRD-K63778487-001-02-8            H-CBLD-003-4                  treated
# 8790  BRD-K16670438-001-02-5            H-CBLD-003-4                  treated
# 8791  BRD-K36882679-001-02-0            H-CBLD-003-4                  treated
# 8792  BRD-K19662956-001-02-1            H-CBLD-003-4                  treated
# 8793  BRD-K56183302-001-02-3            H-CBLD-003-4                  treated
#
#       Metadata_Plate  SINGLE_CONC  PUBCHEM_ACTIVITY_SCORE  \
# 0              24278         True                     0.0
# 1              24278         True                     0.0
# 2              24278         True                     0.0
# 3              24278         True                     0.0
# 4              24278         True                     0.0
# ...              ...          ...                     ...
# 8789           24740        False                     0.0
# 8790           24740        False                     0.0
# 8791           24740        False                     0.0
# 8792           24740        False                     0.0
# 8793           24740        False                     0.0
#
#      PUBCHEM_ACTIVITY_OUTCOME  Metadata_mmoles_per_liter  ...  \
# 0                    Inactive                   5.000000  ...
# 1                    Inactive                   5.000000  ...
# 2                    Inactive                   2.379167  ...
# 3                    Inactive                   5.000000  ...
# 4                    Inactive                   5.000000  ...
# ...                       ...                        ...  ...
# 8789                 Inactive                   5.062167  ...
# 8790                 Inactive                   5.113747  ...
# 8791                 Inactive                   5.049401  ...
# 8792                 Inactive                   5.025291  ...
# 8793                 Inactive                   5.043599  ...
#
#       Nuclei_Texture_Variance_DNA_5_0  Nuclei_Texture_Variance_ER_10_0  \
# 0                           -0.061549                        -0.133824
# 1                            0.098785                        -0.029717
# 2                            0.208695                        -0.024429
# 3                            0.078186                        -0.005418
# 4                           -0.049773                        -0.120946
# ...                               ...                              ...
# 8789                        -0.107988                        -0.067696
# 8790                        -0.271176                        -0.018774
# 8791                         0.022377                        -0.033583
# 8792                        -0.049191                        -0.046927
# 8793                         0.017946                        -0.076074
#
#       Nuclei_Texture_Variance_ER_3_0  Nuclei_Texture_Variance_ER_5_0  \
# 0                          -0.130796                       -0.131496
# 1                          -0.036163                       -0.049478
# 2                          -0.044756                       -0.048945
# 3                          -0.038088                       -0.036953
# 4                          -0.057446                       -0.074382
# ...                              ...                             ...
# 8789                       -0.106654                       -0.078256
# 8790                       -0.137886                       -0.113983
# 8791                        0.021928                        0.004868
# 8792                       -0.009726                       -0.001119
# 8793                       -0.080742                       -0.064154
#
#       Nuclei_Texture_Variance_Mito_10_0  Nuclei_Texture_Variance_Mito_3_0  \
# 0                             -0.153068                         -0.156526
# 1                             -0.122305                         -0.091394
# 2                             -0.091941                         -0.096263
# 3                             -0.075759                         -0.110328
# 4                             -0.102800                         -0.090232
# ...                                 ...                               ...
# 8789                          -0.038353                         -0.034741
# 8790                          -0.061528                         -0.082561
# 8791                           0.013618                          0.035613
# 8792                          -0.044611                         -0.062832
# 8793                          -0.066689                         -0.073823
#
#       Nuclei_Texture_Variance_Mito_5_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                            -0.125545                          0.107378
# 1                            -0.115040                          0.200919
# 2                            -0.109370                          0.053506
# 3                            -0.092795                          0.107877
# 4                            -0.095308                          0.124821
# ...                                ...                               ...
# 8789                         -0.035673                         -0.004637
# 8790                         -0.073975                         -0.117175
# 8791                          0.017948                          0.050071
# 8792                         -0.094449                          0.034307
# 8793                         -0.061546                         -0.022567
#
#       Nuclei_Texture_Variance_RNA_3_0  Nuclei_Texture_Variance_RNA_5_0
# 0                            0.023594                         0.045900
# 1                            0.124473                         0.153696
# 2                            0.038483                         0.040109
# 3                            0.034836                         0.063032
# 4                            0.014721                         0.040721
# ...                               ...                              ...
# 8789                        -0.003541                        -0.009770
# 8790                        -0.100076                        -0.087587
# 8791                         0.026995                         0.040520
# 8792                         0.006336                         0.011479
# 8793                        -0.038925                        -0.044059
#
# [8794 rows x 1794 columns]
