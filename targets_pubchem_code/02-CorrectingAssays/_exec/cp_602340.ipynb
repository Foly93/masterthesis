# %% [markdown]
# ### Correction of the ML-Ready Cell-Painting Data Sets
# #### Prerequisite
# This notebook is part of the master thesis of Luis Vollmers. It uses the cell paintin data set of Bray et al. and the goal of the project is to predict pubchem assay data. Originally this notebook was concerned with pubchem AID 1030 but this might be subject to change.
# #### Introduction
# The datasets generated in ml_ready of step 01 comprise several mistakes that have been made and that need to be corrected within this jupyter notebook. Mostly, the compounds listed in the rows of the ML-ready dataframes are not unique, due to a misunderstanding stemming from the Bray et al Cell-Painting paper. It was stated that the Metadata_broad_sample is a unique identifier which was found to be wrong. Identical compounds which were used in different concentrations and/or on different well-plates were assigned different Metadata_broad_sample values. This needs to be corrected as well as the averaging over the different column values. In the data columns, the cell painting features are listed and so far the algorithm just kept the first concentration and took the average of the respective multiplicates. The correct way of doing it however is to check how many concentrations are present and then take the median of the concentration that is most frequent which is done by this jupyter notebook.
# #### Summary of the steps in this notebook
# 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# 2. Reintroduce the center median data into the pubchem df
# 3. Treat the multi-concentration Compounds adequately
# 4. Export the output

# %%
import pandas as pd

# %% [markdown]
# #### 1. Import the ML-ready pubchem-assay and the preprocessed cell-painting raw data
# - Inputs are taken from the directory for step 1 of the pubchem assays and from the preprocessing directory
# - the data from cp_1030 is erroneous but the meta data is needed for the overlap with the center median data
# - therefore filter the df for the metadata

# %%
# load the data into RAM 'cp_1030' can be used as a variable for a bash script
dataset_path='../../01-FilteringAssays/ml_ready/cp_602340.csv'
df = pd.read_csv(dataset_path, index_col=0).drop(axis=1,columns=['Unnamed: 0.1'])

# read the cell-painting data into RAM
cp = pd.read_csv('../../../preprocessing/cp_center_median.csv', index_col=0)

# define the meta cols of the pubchem assays that are relevant and filter the df 
meta_cols = ['Metadata_broad_sample','PUBCHEM_ACTIVITY_OUTCOME', 'PUBCHEM_ACTIVITY_SCORE']
df = df.loc[:,meta_cols]

# %% [markdown]
# #### 2. Reintroduce the Center Median Data into the Pubchem DF
# - the common column is Metadata_broad_sample which was responsible for the errors in the first place
# - it is actually the only identifier column that is left in the ML-ready df
# - the inner merge makes sure that only rows are kept that can be found in both dataframes

# %%
# merge the cp and the assay data on the common column
merged = pd.merge(left=cp, right=df, on='Metadata_broad_sample', how='inner')

# %%
# this cell calculates the number of rows expected from the final dataframe
multi_list = []
concs_list = merged.CAN_SMILES.value_counts().to_list()

for i in concs_list:
    if i > 1:
        multi_list.append(i)
        
merged.shape[0]-sum(multi_list)+len(multi_list)
# Out:
# 19813

# %% [markdown]
# #### 3. Treat the multi-concentration Compounds adequately
# - this step is the only one that needs to be conducted manually
# - first look at the multi conc compounds and determine how to treat them
# - in this case the concentrations that are less frequent are dropped and the remaining ones are calculated into median
# - for that purpose the merged DF is split into data and meta columns and only the data columns are treated accordingly
# - the groupby method is used to calculate the compound wise median
# - the single concentrations are already calculated so only the multi concs are actually computed herein

# %%
# this cell checks hoif 2 different concentrations are present per compound
# sees if the two concs differ only alittle bit and writes the compounds which are highly differing into alist
# it also writes the more frequent concentration into that same list
multi_merged = merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']]

len_list = []
compound_list = []

for i,j in multi_merged.groupby("CAN_SMILES"):
    len_list.append(j.Metadata_mmoles_per_liter.value_counts().shape[0])
    
if all(flag == 2 for flag in len_list):
    for i,j in multi_merged.groupby("CAN_SMILES"):
        avr = (j.Metadata_mmoles_per_liter.value_counts().index.to_list()[0] + j.Metadata_mmoles_per_liter.value_counts().index.to_list()[1])/2
        dev = abs(avr - j.Metadata_mmoles_per_liter.value_counts().index.to_list()[1])
        if dev/avr > 0.1:
            compound_list.append([i,j.Metadata_mmoles_per_liter.value_counts().index.to_list()[0]])
else:
    print("higher doubly concs or all singly! ")
    
compound_list
# Out:
# [['CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1',
#   2.12011089706471],
#  ['COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1', 3.76887168273337],
#  ['C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C(C)(C)[C@@H]5CC[C@@]4(C)[C@]3(C)CC[C@@]2(C(=O)O)CC[C@H]1C',
#   2.18961966131313],
#  ['Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21', 3.58050745959344]]

# %%
for compound in compound_list:
    merged = merged.drop(merged[(merged.Metadata_mmoles_per_liter != compound[1]) & (merged.CAN_SMILES==compound[0])].index)
# Out:
# 24338

# %%
# Quality Control step that makes sure only the relevant rows with the most concentrations are kept
multi_merged = merged.query('SINGLE_CONC==False').loc[:,['CAN_SMILES','Metadata_mmoles_per_liter']]
for i,j in multi_merged.groupby("CAN_SMILES"):
    print("{}\n{}\n\n".format(i,j.Metadata_mmoles_per_liter.value_counts()))
# Out:
# CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1
# 2.120111    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.989704    12
# 5.010584     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.005957    8
# 5.017707    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@@H]1C
# 5.062167    12
# 5.021036     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 5.095349    12
# 4.997005     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.225374    12
# 5.017207     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.008734    12
# 4.837163    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C
# 5.062843    12
# 5.001327    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 4.962919    12
# 5.000125    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CC(C)COC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.104492    12
# 5.026557     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@@H]2O[C@@H](CC(=O)NCC3CCCCC3)CC[C@H]21
# 4.971032    8
# 5.040460    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@@H]2O[C@H](CC(=O)NCC3CCCCC3)CC[C@@H]21
# 5.001511    8
# 4.996119    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@@H]2O[C@H](CC(=O)NCC3CCCCC3)CC[C@H]21
# 4.907639    8
# 5.041447    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C@@H](CC(=O)NCC3CCCCC3)CC[C@@H]21
# 5.048499    8
# 5.000000    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C@@H](CC(=O)NCC3CCCCC3)CC[C@H]21
# 5.004178    8
# 5.039360    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C@H](CC(=O)NCC3CCCCC3)CC[C@@H]21
# 4.911585    8
# 5.001511    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C@H](CC(=O)NCC3CCCCC3)CC[C@H]21
# 4.983182    8
# 5.099641    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CNC[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 5.002447    8
# 4.823422    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CNC[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.020006    12
# 5.005743    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# CNC[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.03660    12
# 4.91059    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COC(=O)Nc1nc2cc(SC(C)C)ccc2[nH]1
# 3.768872    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1
# 5.149126    12
# 5.011553    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccc(S(=O)(=O)N(C)C[C@@H]2OCc3cn(nn3)CCCC(=O)N([C@H](C)CO)C[C@H]2C)cc1
# 5.017851    12
# 5.043529    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccc(S(=O)(=O)N(C)C[C@H]2OCc3cn(nn3)CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1
# 5.034521    12
# 5.099189    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1cccc(S(=O)(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@@H]2C)c1
# 5.006259    12
# 5.031989    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1cccc(S(=O)(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)c1
# 4.932734    12
# 5.008023    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1cccc(S(=O)(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@H]2C)c1
# 5.114838    12
# 5.012853    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.897774    12
# 5.008402    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1CN(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 4.875204    12
# 5.019548    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1CN(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.034544    12
# 5.002851    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 4.885897    12
# 5.012548    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 5.175297    12
# 5.021536    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.032887    12
# 5.009490    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# COc1ccccc1S(=O)(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@H]1C
# 4.939828    12
# 5.012248    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)CCC(F)(F)F)OCc2cnnn2CCCC1=O
# 5.048502    12
# 5.035292     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Cc2ccccc2)OCc2cnnn2CCCC1=O
# 5.003856    12
# 5.025684    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)NC2CCCCC2)OCc2cnnn2CCCC1=O
# 5.246041    12
# 5.028574     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2ccc(N3CCCCC3)cc2)OCc2cnnn2CCCC1=O
# 5.089334    12
# 5.004380     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Nc2cccc(Oc3ccccn3)c2)OCc2cnnn2CCCC1=O
# 5.015640    12
# 5.141794    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)Oc2cccc3ccccc23)OCc2cnnn2CCCC1=O
# 5.011766    12
# 4.904688    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2cc(-c3ccccc3)on2)OCc2cnnn2CCCC1=O
# 5.023000    12
# 4.870857    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc(N3CCN(C)CC3)cc2)OCc2cnnn2CCCC1=O
# 5.040004    12
# 5.014369    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccc3ccn(C)c3c2)OCc2cnnn2CCCC1=O
# 5.100838    12
# 5.016750     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)C(=O)c2ccncc2)OCc2cnnn2CCCC1=O
# 5.025291    12
# 5.017451     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@@H](CN(C)S(=O)(=O)c2ccc3ccccc3c2)OCc2cnnn2CCCC1=O
# 4.997736    12
# 4.972897    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)C2CC2)OCc2cn(nn2)CCCC1=O
# 5.002573    8
# 5.005668    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)CCC(F)(F)F)OCc2cn(nn2)CCCC1=O
# 5.027984    8
# 5.041397    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)CCC(F)(F)F)OCc2cnnn2CCCC1=O
# 5.089254    12
# 5.010037     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2ccccc2)OCc2cn(nn2)CCCC1=O
# 5.202596    8
# 5.008241    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Cc2ccccc2)OCc2cnnn2CCCC1=O
# 4.980771    12
# 5.015672    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)NC2CCCCC2)OCc2cn(nn2)CCCC1=O
# 5.008343    8
# 4.902354    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)NC2CCCCC2)OCc2cnnn2CCCC1=O
# 5.139115    12
# 5.007410     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccc(N3CCCCC3)cc2)OCc2cnnn2CCCC1=O
# 5.079465    12
# 5.016685    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2cccc(Oc3ccccn3)c2)OCc2cn(nn2)CCCC1=O
# 5.021066    8
# 5.073469    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2cccc(Oc3ccccn3)c2)OCc2cnnn2CCCC1=O
# 5.061389    12
# 5.015037     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccccc2C(F)(F)F)OCc2cn(nn2)CCCC1=O
# 4.942332    8
# 5.010630    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc(N3CCOCC3)c2)OCc2cn(nn2)CCCC1=O
# 4.929732    8
# 5.019657    6
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Nc2ccnc(N3CCOCC3)c2)OCc2cnnn2CCCC1=O
# 5.026834    12
# 5.020381    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)Oc2cccc3ccccc23)OCc2cnnn2CCCC1=O
# 4.920903    12
# 5.027810    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2cc(-c3ccccc3)on2)OCc2cn(nn2)CCCC1=O
# 5.091180    12
# 5.022433    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc(N3CCN(C)CC3)cc2)OCc2cn(nn2)CCCC1=O
# 4.878387    8
# 5.002223    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc(N3CCN(C)CC3)cc2)OCc2cnnn2CCCC1=O
# 5.036903    12
# 5.020758     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3ccn(C)c3c2)OCc2cn(nn2)CCCC1=O
# 5.126058    12
# 5.002624    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccc3ccn(C)c3c2)OCc2cnnn2CCCC1=O
# 4.918819    12
# 5.005940     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc2)OCc2cn(nn2)CCCC1=O
# 5.003644    8
# 5.206659    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)C(=O)c2ccncc2)OCc2cnnn2CCCC1=O
# 4.925582    12
# 5.018365     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc(C(F)(F)F)cc2)OCc2cnnn2CCCC1=O
# 5.244719    12
# 5.014517     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3c(c2)OCCN3C)OCc2cnnn2CCCC1=O
# 5.109445    8
# 4.993672    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3c(c2)OCO3)OCc2cnnn2CCCC1=O
# 5.056964    12
# 5.003469     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccc3cccnc3c2)OCc2cnnn2CCCC1=O
# 5.102371    12
# 5.011211     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccc3c2OCCCO3)OCc2cnnn2CCCC1=O
# 5.264151    12
# 5.010782     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2ccccc2C(F)(F)F)OCc2cnnn2CCCC1=O
# 5.056832    12
# 5.010473     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)Cc2cccnc2)OCc2cnnn2CCCC1=O
# 5.283297    12
# 5.016255     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(=O)(=O)c2ccc3ccccc3c2)OCc2cn(nn2)CCCC1=O
# 5.066968    12
# 5.017491    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(=O)(=O)c2ccc3ccccc3c2)OCc2cnnn2CCCC1=O
# 5.045707    12
# 5.022169    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(=O)(=O)c2ccccc2F)OCc2cn(nn2)CCCC1=O
# 5.008109    12
# 5.004353    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H](CO)N1C[C@@H](C)[C@H](CN(C)S(C)(=O)=O)OCc2cnnn2CCCC1=O
# 5.151803    12
# 5.002108    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)NC1CCCCC1
# 5.015898    12
# 4.786003    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccc2c(c1)OCO2
# 5.004310    12
# 5.224529    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccccc1
# 4.961919    12
# 5.006433     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccccc1C(F)(F)F
# 4.609011    12
# 5.019410     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1
# 5.005918    12
# 4.930417    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Oc1ccc2ccccc2c1
# 5.071692    12
# 5.001179     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.236087    12
# 5.026253    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.000507    12
# 5.213841    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 4.991011    12
# 5.015737    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 5.233043    12
# 5.016112    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.018597    12
# 5.161175    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)S(=O)(=O)c1ccccc1F
# 4.850914    12
# 5.011379    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@H]1CN(C)S(C)(=O)=O
# 5.001828    12
# 5.018968     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)CCC(F)(F)F
# 4.924469    12
# 5.001979     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Cc1ccccc1
# 5.012009    12
# 5.001164    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)NC1CCCCC1
# 5.090647    12
# 5.029130     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.011203    12
# 5.089334    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1
# 5.019215    12
# 5.010308    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.196333    12
# 5.031367    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.019399    12
# 5.123372    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.031349    12
# 5.020710    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 4.958808    12
# 5.011142    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Cc1ccccc1
# 5.024448    12
# 4.913217    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.049170    12
# 5.014625    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.002128    12
# 5.127197    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.082632    12
# 5.003060    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.01496    12
# 5.03280    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 5.028868    12
# 5.162838    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccncc1
# 5.049401    12
# 5.025723     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)Cc1ccc(C(F)(F)F)cc1
# 5.003882    12
# 5.097951    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)Cc1ccc(Oc2ccccc2)cc1
# 5.258519    12
# 5.008943    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)Cc1ccc2c(c1)OCO2
# 5.001650    12
# 5.016804     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)Cc1cccc2c1OCCCO2
# 5.031508    12
# 5.002985    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)Cc1ccccc1C(F)(F)F
# 5.012049    12
# 4.991956    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)Cc1cccnc1
# 5.019238    12
# 4.918746    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.034811    12
# 5.004582     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@@H]1[C@H]2C3=CC[C@@H]4[C@@]5(C)CC[C@H](O)C(C)(C)[C@@H]5CC[C@@]4(C)[C@]3(C)CC[C@@]2(C(=O)O)CC[C@H]1C
# 2.18962    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)C1CC1
# 5.003442    8
# 4.905812    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)CCC(F)(F)F
# 4.880398    12
# 5.003470    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Cc1ccccc1
# 5.189670    12
# 5.002088    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1ccc2c(c1)OCO2
# 5.026116    12
# 5.178240    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1cccc(Oc2ccccn2)c1
# 4.965743    12
# 4.995608    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1ccccc1
# 5.005154    12
# 4.921157    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1ccccc1C(F)(F)F
# 5.107492    12
# 5.015670     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.010387    12
# 4.975108    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.020241    12
# 5.046452    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1ccncc1
# 5.015570    12
# 5.113564    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)S(=O)(=O)c1ccccc1F
# 4.925102    8
# 5.029074    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)S(C)(=O)=O
# 5.082673    12
# 5.028348    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.005118    12
# 5.015737    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)CCC(F)(F)F
# 5.123405    12
# 5.016242     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Cc1ccccc1
# 4.987231    12
# 5.009320     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)NC1CCCCC1
# 4.978727    12
# 5.014136    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.012133    12
# 5.255727    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 5.275620    12
# 5.025755     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.184310    12
# 5.040805    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 5.081923    12
# 5.001995    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccncc1
# 5.080316    12
# 5.030905    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.034533    12
# 4.933858    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)S(C)(=O)=O
# 5.064801    12
# 5.030292     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)CCC(F)(F)F
# 5.200085    8
# 5.014210    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1ccc2c(c1)OCO2
# 4.917926    8
# 5.002947    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1cccc(Oc2ccccn2)c1
# 5.063987    8
# 5.004095    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Nc1ccccc1
# 5.025323    8
# 4.806274    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Oc1ccc2ccccc2c1
# 4.976973    12
# 5.018017     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 4.882292    12
# 4.996990     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.009429    12
# 4.937611    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 4.927553    8
# 4.999145    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 4.909627    12
# 5.008353    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)C(=O)c1ccncc1
# 5.069764    8
# 5.000042    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.000022    12
# 4.983639    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2cc(nn2)CO[C@@H]1CN(C)S(=O)(=O)c1ccccc1F
# 4.993173    8
# 5.044176    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)C1CC1
# 5.001186    12
# 5.017340     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)CCC(F)(F)F
# 4.930435    12
# 5.004268     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Cc1ccccc1
# 5.097054    12
# 5.014458     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)NC1CCCCC1
# 5.225993    12
# 5.005394     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1cccc(Oc2ccccn2)c1
# 5.01228    12
# 5.23979    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccccc1F
# 4.893264    12
# 5.020627     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1
# 5.020808    12
# 5.014093     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.027891    12
# 5.006436    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.007248    12
# 5.015595     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1ccc2ccn(C)c2c1
# 5.022663    12
# 5.041201    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)C(=O)c1ccncc1
# 5.043599    12
# 5.026888     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)Cc1ccc(Oc2ccccc2)cc1
# 5.025568    12
# 5.096569    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)Cc1ccc2c(c1)OCO2
# 5.005383    12
# 5.195511    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)Cc1ccc2cccnc2c1
# 5.113747    12
# 5.009231     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)Cc1cccc2c1OCCCO2
# 5.124180    12
# 5.031982    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.015189    12
# 5.011856     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@@H]1CN(C)S(C)(=O)=O
# 5.074768    12
# 5.016244     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Cc1ccccc1
# 5.027192    12
# 5.041802    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)NC1CCCCC1
# 4.915711    8
# 5.026342    6
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1ccc(N2CCCCC2)cc1
# 5.003826    8
# 5.272940    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1cccc(Oc2ccccn2)c1
# 5.003773    12
# 4.952672    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Nc1ccnc(N2CCOCC2)c1
# 5.021688    12
# 5.124438    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)Oc1cccc2ccccc12
# 4.971403    12
# 5.019240    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1cc(-c2ccccc2)on1
# 5.172406    12
# 5.023732     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)C(=O)c1ccc(N2CCN(C)CC2)cc1
# 5.052025    12
# 5.025691    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# C[C@H]1CN([C@H](C)CO)C(=O)CCCn2nncc2CO[C@H]1CN(C)S(=O)(=O)c1ccc2ccccc2c1
# 5.022848    12
# 4.902670    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@@H]2C)cc1
# 4.994290    12
# 5.000866     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1
# 5.048398    12
# 4.996151    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1
# 5.155850    12
# 5.003397    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@@H](C)CO)C[C@H]2C)cc1
# 5.008339    12
# 5.005205     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1ccc(OC(=O)N(C)C[C@H]2OCc3cnnn3CCCC(=O)N([C@H](C)CO)C[C@@H]2C)cc1
# 5.015245    12
# 5.013109    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.997022    8
# 5.292266    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@@H]1OCc2cnnn2CCCC(=O)N([C@@H](C)CO)C[C@H]1C
# 4.576343    12
# 5.022708    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cn(nn2)CCCC(=O)N([C@@H](C)CO)C[C@@H]1C
# 4.945691    12
# 5.014792     9
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cc1noc(C)c1NC(=O)N(C)C[C@H]1OCc2cnnn2CCCC(=O)N([C@H](C)CO)C[C@@H]1C
# 5.013564    12
# 5.048845    12
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# Cn1c(-c2ccc3c(c2)OCO3)cc(=O)c2ccccc21
# 3.580507    8
# Name: Metadata_mmoles_per_liter, dtype: int64
#
#
# N#C[C@H]1N[C@H](CO)[C@@H]1c1ccc(/C=C/c2ccccc2)cc1
# 5.017856    8
# 5.020013    8
# Name: Metadata_mmoles_per_liter, dtype: int64

# %%
# define a list of the all columns of the merged data frame
all_cols = merged.columns.to_list()
# redefine meta columns with the meta information of the cell painting assay
meta_cols = ['CAN_SMILES','CPD_SMILES','Metadata_broad_sample','Metadata_Plate_Map_Name','Metadata_ASSAY_WELL_ROLE','Metadata_Plate','SINGLE_CONC','PUBCHEM_ACTIVITY_SCORE','PUBCHEM_ACTIVITY_OUTCOME']

# %%
# data cols are basically all columns without the meta data. hence the forloop that removes those from data_cols
data_cols = all_cols
for item in meta_cols:
    data_cols.remove(item)
    
# afterwards the 'CAN_SMILES' column is inserted at the first position
data_cols.insert(0,'CAN_SMILES')

# %%
# the merged data frame is split into two dataframes containing meta and raw data information
merged_data = merged.loc[:,data_cols]
merged_meta = merged.loc[:,meta_cols]

# %%
# this command takes the compound wise median of the data
merged_data = merged_data.groupby('CAN_SMILES').median().reset_index()

# %% [markdown]
# #### 4. Export the Output
# - as a last step the only thing that needs to be done is to merge the meta and data columns back into one DF
# - a bit of a clean up needs to be done since the merge command creates suplicates, which can be safely deleted
# - output in csv format named according to the pubchem AID

# %%
# the median data is merged back with the meta data
merged = pd.merge(left=merged_meta, right=merged_data, on='CAN_SMILES', how='left')

# %%
# merging generally keeps all rows in both frames so that duplicates are generated, which get hereby deleted
merged = merged.drop_duplicates(subset='CAN_SMILES')

# %%
merged.to_csv('../_output/cp_602340.csv',index=False)

# %%
pd.read_csv('../_output/cp_602340.csv') # only uncomment for quality control purposes, i.e. visual conformation
# Out:
#                                               CAN_SMILES  \
# 0                               COc1cc(OC)c2ccc(=O)oc2c1
# 1           O=C(CCCN1CCC(O)(c2ccc(Br)cc2)CC1)c1ccc(F)cc1
# 2                       Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1
# 3      CCCCC1(COC(=O)CCC(=O)O)C(=O)N(c2ccccc2)N(c2ccc...
# 4          COC(=O)c1c(C)[nH]c(C)c1C(=O)c1ccccc1Cc1ccccc1
# ...                                                  ...
# 19808  CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C...
# 19809  CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C...
# 19810  CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@@H]2O[...
# 19811  N#C[C@H]1N[C@H](CO)[C@@H]1c1ccc(/C=C/c2ccccc2)cc1
# 19812  CN1C(=O)c2cc(NC(=O)c3cccc(F)c3)ccc2OC[C@H]2O[C...
#
#                                               CPD_SMILES  \
# 0                               COc1cc(OC)c2ccc(=O)oc2c1
# 1           OC1(CCN(CCCC(=O)c2ccc(F)cc2)CC1)c1ccc(Br)cc1
# 2                       Cc1oncc1C(=O)Nc1ccc(cc1)C(F)(F)F
# 3      CCCCC1(COC(=O)CCC(O)=O)C(=O)N(N(C1=O)c1ccccc1)...
# 4          COC(=O)c1c(C)[nH]c(C)c1C(=O)c1ccccc1Cc1ccccc1
# ...                                                  ...
# 19808  CN1[C@@H]2CC[C@H](CC(=O)NCC3CCCCC3)O[C@@H]2COc...
# 19809  CN1[C@H]2CC[C@H](CC(=O)NCC3CCCCC3)O[C@@H]2COc2...
# 19810  CN1[C@@H]2CC[C@@H](CC(=O)NCC3CCCCC3)O[C@H]2COc...
# 19811   OC[C@H]1N[C@H](C#N)[C@H]1c1ccc(\C=C\c2ccccc2)cc1
# 19812  CN1[C@@H]2CC[C@@H](CC(=O)NCC3CCCCC3)O[C@@H]2CO...
#
#         Metadata_broad_sample Metadata_Plate_Map_Name  \
# 0      BRD-K78612426-001-02-6            H-BIOA-007-3
# 1      BRD-K78643075-001-03-3            H-BIOA-007-3
# 2      BRD-K78692225-001-11-2            H-BIOA-007-3
# 3      BRD-K78815826-001-04-7            H-BIOA-007-3
# 4      BRD-K78959463-001-02-5            H-BIOA-007-3
# ...                       ...                     ...
# 19808  BRD-K41878610-001-01-5            H-CBLN-002-4
# 19809  BRD-K96543798-001-03-9            H-CBLN-002-4
# 19810  BRD-K06039860-001-01-4            H-CBLN-002-4
# 19811  BRD-K39376673-001-02-6            H-CBLK-001-4
# 19812  BRD-K31618614-001-02-1            H-CBLN-001-4
#
#       Metadata_ASSAY_WELL_ROLE  Metadata_Plate  SINGLE_CONC  \
# 0                      treated           24278         True
# 1                      treated           24278         True
# 2                      treated           24278         True
# 3                      treated           24278         True
# 4                      treated           24278         True
# ...                        ...             ...          ...
# 19808                  treated           26640        False
# 19809                  treated           26640        False
# 19810                  treated           26640        False
# 19811                  treated           26702        False
# 19812                  treated           26767        False
#
#        PUBCHEM_ACTIVITY_SCORE PUBCHEM_ACTIVITY_OUTCOME  \
# 0                         6.0                 Inactive
# 1                        -1.0                 Inactive
# 2                         9.0                 Inactive
# 3                         4.0                 Inactive
# 4                         0.0                 Inactive
# ...                       ...                      ...
# 19808                     9.0                 Inactive
# 19809                    53.0                 Inactive
# 19810                   -11.0                 Inactive
# 19811                     0.0                 Inactive
# 19812                   -16.0                 Inactive
#
#        Metadata_mmoles_per_liter  ...  Nuclei_Texture_Variance_DNA_5_0  \
# 0                       5.000000  ...                        -0.061549
# 1                       2.379167  ...                         0.208695
# 2                       5.000000  ...                         0.078186
# 3                       5.000000  ...                        -0.049773
# 4                       7.196170  ...                         0.265760
# ...                          ...  ...                              ...
# 19808                   5.021769  ...                        -0.116303
# 19809                   5.024250  ...                        -0.172467
# 19810                   4.974543  ...                        -0.032031
# 19811                   5.018934  ...                        -0.091799
# 19812                   5.041411  ...                        -0.118548
#
#        Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_3_0  \
# 0                            -0.133824                       -0.130796
# 1                            -0.024429                       -0.044756
# 2                            -0.005418                       -0.038088
# 3                            -0.120946                       -0.057446
# 4                             0.033455                        0.009330
# ...                                ...                             ...
# 19808                         0.004567                       -0.058243
# 19809                        -0.035013                       -0.038448
# 19810                        -0.029031                       -0.068881
# 19811                        -0.077381                       -0.120716
# 19812                         0.105450                        0.103621
#
#        Nuclei_Texture_Variance_ER_5_0  Nuclei_Texture_Variance_Mito_10_0  \
# 0                           -0.131496                          -0.153068
# 1                           -0.048945                          -0.091941
# 2                           -0.036953                          -0.075759
# 3                           -0.074382                          -0.102800
# 4                            0.016445                          -0.027188
# ...                               ...                                ...
# 19808                       -0.023243                          -0.105091
# 19809                       -0.048358                          -0.134538
# 19810                       -0.068846                          -0.089828
# 19811                       -0.089105                          -0.120668
# 19812                        0.102403                          -0.191962
#
#        Nuclei_Texture_Variance_Mito_3_0  Nuclei_Texture_Variance_Mito_5_0  \
# 0                             -0.156526                         -0.125545
# 1                             -0.096263                         -0.109370
# 2                             -0.110328                         -0.092795
# 3                             -0.090232                         -0.095308
# 4                             -0.029056                         -0.048618
# ...                                 ...                               ...
# 19808                         -0.110600                         -0.099656
# 19809                         -0.132677                         -0.129843
# 19810                         -0.102124                         -0.113365
# 19811                         -0.107559                         -0.114923
# 19812                         -0.264119                         -0.270097
#
#        Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_3_0  \
# 0                              0.107378                         0.023594
# 1                              0.053506                         0.038483
# 2                              0.107877                         0.034836
# 3                              0.124821                         0.014721
# 4                              0.198655                         0.115654
# ...                                 ...                              ...
# 19808                         -0.041102                        -0.040140
# 19809                         -0.073042                        -0.067570
# 19810                         -0.114226                        -0.095374
# 19811                         -0.018314                        -0.037562
# 19812                         -0.138615                        -0.167077
#
#        Nuclei_Texture_Variance_RNA_5_0
# 0                             0.045900
# 1                             0.040109
# 2                             0.063032
# 3                             0.040721
# 4                             0.141480
# ...                                ...
# 19808                        -0.018351
# 19809                        -0.065889
# 19810                        -0.108374
# 19811                        -0.021932
# 19812                        -0.153723
#
# [19813 rows x 1794 columns]
